# %% [markdown]
# #### Parsing JSON, reading as dataframe and saving as csv format

# %%
import json
import numpy as np
import pandas as pd

# %%
## reading it as json

data_ = []
for line in open('12147_final_df.json', 'r'):
    data_.append(json.loads(line))

# %%
## reading it as pandas dataframe

df = pd.read_json('12147_final_df.json', lines=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385052 entries, 0 to 385051
# Data columns (total 87 columns):
# _version_                     369539 non-null float64
# available_price               385052 non-null float64
# bid                           15513 non-null float64
# brand                         15513 non-null object
# category                      15513 non-null object
# color                         385042 non-null object
# country                       385052 non-null object
# crawl_date                    385052 non-null int64
# crawl_time                    385052 non-null datetime64[ns]
# crawl_type                    385052 non-null object
# datasource_s                  369539 non-null object
# description                   385052 non-null object
# docs                          205 non-null object
# extracted_attributes          369539 non-null object
# flag                          369539 non-null float64
# images                        385052 non-null object
# index                         369539 non-null float64
# is_published                  15513 non-null float64
# match__version_               369539 non-null float64
# match_available_price         385050 non-null float64
# match_brand                   15349 non-null object
# match_category                12675 non-null object
# match_color                   384467 non-null object
# match_country                 385052 non-null object
# match_crawl_date              385052 non-null int64
# match_crawl_time              385052 non-null datetime64[ns]
# match_crawl_type              385052 non-null object
# match_datasource_s            369539 non-null object
# match_description             378701 non-null object
# match_extracted_attributes    373883 non-null object
# match_images                  379348 non-null object
# match_match_type              15513 non-null object
# match_material                369539 non-null object
# match_mrp                     380953 non-null object
# match_norm_brand              369539 non-null object
# match_norm_category           369539 non-null object
# match_offers                  369539 non-null object
# match_rank                    369539 non-null float64
# match_raw_brand               369539 non-null object
# match_raw_category            369539 non-null object
# match_raw_meta                381552 non-null object
# match_raw_subcategory         369539 non-null object
# match_seed_url                385052 non-null object
# match_seed_urlh               385052 non-null object
# match_shipping_charges        369539 non-null object
# match_shipping_time           369539 non-null object
# match_size                    384737 non-null object
# match_sku                     384848 non-null object
# match_sku_s                   369539 non-null object
# match_source                  385052 non-null object
# match_specification           369641 non-null object
# match_status                  369539 non-null float64
# match_stock                   385046 non-null object
# match_subcategory             10203 non-null object
# match_thumbnail               385039 non-null object
# match_timestamp               369539 non-null object
# match_title                   385051 non-null object
# match_title_s                 369539 non-null object
# match_type                    385052 non-null object
# match_upc                     378092 non-null object
# match_url                     385052 non-null object
# match_urlh                    385052 non-null object
# mrp                           385052 non-null float64
# norm_brand                    369539 non-null object
# product_type                  0 non-null float64
# raw_brand                     385052 non-null object
# raw_category                  369539 non-null object
# raw_meta                      369539 non-null object
# raw_subcategory               369539 non-null object
# seed_url                      385052 non-null object
# seed_urlh                     369539 non-null object
# size                          385052 non-null object
# sku                           385052 non-null object
# source                        385052 non-null object
# specification                 369539 non-null object
# status                        385052 non-null int64
# stock                         385052 non-null object
# subcategory                   15513 non-null object
# tagged_data                   15513 non-null object
# task_description              369539 non-null object
# task_type                     369539 non-null object
# thumbnail                     385052 non-null object
# timestamp                     369539 non-null datetime64[ns]
# title                         385052 non-null object
# upc                           385049 non-null object
# url                           385052 non-null object
# urlh                          385052 non-null object
# dtypes: datetime64[ns](3), float64(12), int64(3), object(69)
# memory usage: 255.6+ MB

# %%
## saving data as csv file

df.to_csv('ecomm_full.csv', encoding='utf-8')

# %%
y = df['match_seed_urlh']
df.drop(['match_seed_urlh'], axis=1)

# %%
## train test split - 80:20
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42)
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\sklearn\utils\validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'

# %%
X_train['match_seed_urlh'] = y
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train.head()
# Out:
#            _version_  available_price  bid brand category     color country  \
# 107867  1.688998e+18            99.97  NaN  None     None     IVORY     usa
# 366665  1.693043e+18            74.00  NaN  None     None     IVORY     usa
# 135770  1.693002e+18           525.00  NaN  None     None     BLACK     usa
# 15283   1.692988e+18            17.99  NaN  None     None      Pink     usa
# 66925   1.693003e+18           415.00  NaN  None     None  No Color     usa
#
#         crawl_date              crawl_time crawl_type  ... subcategory  \
# 107867    20210116 1970-08-22 21:55:16.050    product  ...        None
# 366665    20210301 1970-08-22 21:58:21.152    product  ...        None
# 135770    20210301 1970-08-22 21:58:21.050    product  ...        None
# 15283     20210301 1970-08-22 21:58:21.050    product  ...        None
# 66925     20210301 1970-08-22 21:58:21.050    product  ...        None
#
#        tagged_data task_description       task_type  \
# 107867        None                   Exact Matching
# 366665        None                   Exact Matching
# 135770        None                   Exact Matching
# 15283         None                   Exact Matching
# 66925         None                   Exact Matching
#
#                                                 thumbnail  \
# 107867  https://n.nordstrommedia.com/id/sr3/75709733-5...
# 366665  https://n.nordstrommedia.com/id/sr3/d2b3a7c7-b...
# 135770  https://n.nordstrommedia.com/id/sr3/8a2e81b1-a...
# 15283   https://n.nordstrommedia.com/id/sr3/3b9b96a4-9...
# 66925   https://n.nordstrommedia.com/id/sr3/de3703f2-1...
#
#                      timestamp  \
# 107867 2021-01-15 23:32:29.193
# 366665 2021-03-01 15:19:08.011
# 135770 2021-03-01 04:22:43.986
# 15283  2021-03-01 00:34:33.180
# 66925  2021-03-01 04:42:59.320
#
#                                                     title          upc  \
# 107867              Theory Silk Shell Top IVORY  Small---  1.92649e+11
# 366665  Chantelle Lingerie C Magnifique Seamless Unlin...  3.34044e+12
# 135770  RAG AND BONE rag & bone Shiloh Combat Boot (Wo...  1.90298e+11
# 15283   Bixbee Kitty Water Resistant Lunchbox (Kids) P...  8.59466e+11
# 66925   Maison Francis Kurkdjian Paris Grand Soir Eau ...  3.70056e+12
#
#                                                       url  \
# 107867  https://www.nordstrom.com/s/5719561#!#31367672...
# 366665  https://www.nordstrom.com/s/3317226#!#58848984...
# 135770  https://www.nordstrom.com/s/5363216#!#24688751...
# 15283   https://www.nordstrom.com/s/4936050#!#17093500...
# 66925   https://www.nordstrom.com/s/5495537#!#27585386...
#
#                                             urlh
# 107867  33adb6d3fdf9579530acb2ad487d61747753a6d1
# 366665  7b868afc9034fd75fd31c09b84e8e3cad0b07517
# 135770  0b2a4aaae4404efbbbdda53e3d1c21184ec9ea5c
# 15283   54f2c7ee28d27aaa202815abd36fa6b1c27145a6
# 66925   5a3b57e7184415149f723762eec7314b5f22814f
#
# [5 rows x 87 columns]

# %%
X_train.to_csv('ecomm_train.csv', encoding='utf-8')

# %%
## selecting only relevant text feature columns

corpus = X_train[['title', 'description', 'match_description', 'color']]

# %%
corpus.head()
# Out:
#                                                     title  \
# 107867              Theory Silk Shell Top IVORY  Small---
# 366665  Chantelle Lingerie C Magnifique Seamless Unlin...
# 135770  RAG AND BONE rag & bone Shiloh Combat Boot (Wo...
# 15283   Bixbee Kitty Water Resistant Lunchbox (Kids) P...
# 66925   Maison Francis Kurkdjian Paris Grand Soir Eau ...
#
#                                               description  \
# 107867
# 366665  Designed to minimize your bustline by one inch...
# 135770  Side panels lend a bit of give to tough, comba...
# 15283   The face of a pretty kitty defines a playful w...
# 66925   <strong>What it is</strong>: A sophisticated a...
#
#                                         match_description     color
# 107867                                                        IVORY
# 366665  Full-coverage support with a delightful subtle...     IVORY
# 135770                                                        BLACK
# 15283                                                          Pink
# 66925                                                      No Color

# %%
## applying lowercase function to text columns

corpus['title'] = corpus['title'].str.lower()
corpus['description'] = corpus['description'].str.lower()
corpus['match_description'] = corpus['match_description'].str.lower()
corpus['color'] = corpus['color'].str.lower()
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## removing special chars => !"#$%&\'()*+,-./:;<=>?@[\\]^_{|}~`
import string
import re

def remove_special_chars(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
## replacing '&' with 'and' keyword to conserve semantic meaning of sentences

corpus['title'] = corpus['title'].str.replace('&','and')
corpus['description'] = corpus['description'].str.replace('&','and')
corpus['match_description'] = corpus['match_description'].str.replace('&','and')
corpus['color'] = corpus['color'].str.replace('&','and')
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## removing html-tags from data

corpus['title'] = corpus['title'].str.replace(r'<[^<>]*>', '', regex=True)
corpus['description'] = corpus['description'].str.replace(r'<[^<>]*>', '', regex=True)
corpus['match_description'] = corpus['match_description'].str.replace(r'<[^<>]*>', '', regex=True)
corpus['color'] = corpus['color'].str.replace(r'<[^<>]*>', '', regex=True)
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
corpus['description'] = corpus['description'].str.replace(r'what it is:', '')
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
## removing numbers from text strings

corpus['title'] = corpus['title'].str.replace('\d+', '')  
corpus['description'] = corpus['description'].str.replace('\d+', '')
corpus['match_description'] = corpus['match_description'].str.replace('\d+', '')
corpus['color'] = corpus['color'].str.replace('\d+', '')
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Removing NaN elements

corpus['title'] = corpus.fillna({'title':''})
corpus['description'] = corpus.fillna({'description':''})
corpus['match_description'] = corpus.fillna({'match_description':''})
corpus['color'] = corpus.fillna({'color':''})
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
## making some values as str to solve "NaN" value issue

corpus['title'] = corpus['title'].astype(str)
corpus['description'] = corpus['description'].astype(str)
corpus['match_description'] = corpus['match_description'].astype(str)
corpus['color'] = corpus['color'].astype(str)
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## removing unwanted chars

corpus["title"] = corpus["title"].apply(lambda text: remove_special_chars(text))
corpus["description"] = corpus["description"].apply(lambda text: remove_special_chars(text))
corpus["match_description"] = corpus["match_description"].apply(lambda text: remove_special_chars(text))
corpus["color"] = corpus["color"].apply(lambda text: remove_special_chars(text))
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
corpus.head(20)
# Out:
#                                                     title  \
# 107867                 theory silk shell top ivory  small
# 366665  chantelle lingerie c magnifique seamless unlin...
# 135770  rag and bone rag and bone shiloh combat boot w...
# 15283   bixbee kitty water resistant lunchbox kids pin...
# 66925   maison francis kurkdjian paris grand soir eau ...
# 283289  estee lauder estée lauder double wear light so...
# 21382    peter millar hyperlight bit loafer men black  11
# 376720  bernie mev fresh buttercup sandal women light ...
# 264581  hourglass vanish flash highlighting stick rose...
# 208868  fjallraven fjällräven vik wool crewneck sweate...
# 10763   nashelle sterling silver initial disc bracelet...
# 141506         felina aubrie boy leg briefs black  xlarge
# 84809   wayf finn metallic daisy double breasted blaze...
# 372879  valentino garavani rockstud slingback pump wom...
# 51626   kurt geiger london chevron quilted leather car...
# 292782          ugg® ascot leather slipper men black  7 m
# 282439  clinique acne solutions acne  line correcting ...
# 60734   allsaints leigh plain toe derby men charcoal g...
# 172400  joules welly print rain boot women brown leopa...
# 174059  michael michael kors denim jacket plus size ri...
#
#                                               description  \
# 107867
# 366665  designed to minimize your bustline by one inch...
# 135770  side panels lend a bit of give to tough combat...
# 15283   the face of a pretty kitty defines a playful w...
# 66925    a sophisticated and concentrated eau de parfu...
# 283289   a 24hour matte makeup foundation that softly ...
# 21382
# 376720  basketweave elastic perfects the custom comfy ...
# 264581   a highlighter that gives skin an instant flas...
# 208868
# 10763   from humble beginnings to a fully staffed ware...
# 141506
# 84809   a sharply tailored menswear silhouette and lus...
# 372879  distinctive pyramid studs highlight the mary j...
# 51626   a trim profile makes this chevronquilted leath...
# 292782  this smartly designed slipper is shaped from e...
# 282439   an acnefighting serum to help target lines wr...
# 60734   a smart creperubber sole adds some pop to a ve...
# 172400
# 174059  made from classic denim and decorated with gle...
#
#                                         match_description              color
# 107867                                                                 ivory
# 366665  fullcoverage support with a delightful subtle ...              ivory
# 135770                                                                 black
# 15283                                                                   pink
# 66925                                                               no color
# 283289  ships free purchase estée lauder foundation an...           1w2 sand
# 21382                                                                  black
# 376720                                                nan  light gold fabric
# 264581  this product is part of space nk  a luxe beaut...    rose gold flash
# 208868                                                                  navy
# 10763                                                      sterling silver t
# 141506  this delicate panty is ultra comfortable and s...              black
# 84809                                                                  olive
# 372879  from the rockstud collection eclectic rockstud...      rose cannelle
# 51626                                                                  black
# 292782                                                                 black
# 282439  what it is   an acne serum developed specifica...           no color
# 60734   fits narrow order one size up lace up plain ro...      charcoal grey
# 172400                                                         brown leopard
# 174059                                                               riviera

# %%
## performing tokenization - breaking sentences into lexical units

import nltk
from nltk.tokenize import word_tokenize

# %%
corpus['title'] = corpus.apply(lambda row: nltk.word_tokenize(row['title']), axis=1)
corpus['description'] = corpus.apply(lambda row: nltk.word_tokenize(row['description']), axis=1)
corpus['match_description'] = corpus.apply(lambda row: nltk.word_tokenize(row['match_description']), axis=1)
corpus['color'] = corpus.apply(lambda row: nltk.word_tokenize(row['color']), axis=1)
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
corpus.head(20)
# Out:
#                                                     title  \
# 107867           [theory, silk, shell, top, ivory, small]
# 366665  [chantelle, lingerie, c, magnifique, seamless,...
# 135770  [rag, and, bone, rag, and, bone, shiloh, comba...
# 15283   [bixbee, kitty, water, resistant, lunchbox, ki...
# 66925   [maison, francis, kurkdjian, paris, grand, soi...
# 283289  [estee, lauder, estée, lauder, double, wear, l...
# 21382   [peter, millar, hyperlight, bit, loafer, men, ...
# 376720  [bernie, mev, fresh, buttercup, sandal, women,...
# 264581  [hourglass, vanish, flash, highlighting, stick...
# 208868  [fjallraven, fjällräven, vik, wool, crewneck, ...
# 10763   [nashelle, sterling, silver, initial, disc, br...
# 141506  [felina, aubrie, boy, leg, briefs, black, xlarge]
# 84809   [wayf, finn, metallic, daisy, double, breasted...
# 372879  [valentino, garavani, rockstud, slingback, pum...
# 51626   [kurt, geiger, london, chevron, quilted, leath...
# 292782  [ugg®, ascot, leather, slipper, men, black, 7, m]
# 282439  [clinique, acne, solutions, acne, line, correc...
# 60734   [allsaints, leigh, plain, toe, derby, men, cha...
# 172400  [joules, welly, print, rain, boot, women, brow...
# 174059  [michael, michael, kors, denim, jacket, plus, ...
#
#                                               description  \
# 107867                                                 []
# 366665  [designed, to, minimize, your, bustline, by, o...
# 135770  [side, panels, lend, a, bit, of, give, to, tou...
# 15283   [the, face, of, a, pretty, kitty, defines, a, ...
# 66925   [a, sophisticated, and, concentrated, eau, de,...
# 283289  [a, 24hour, matte, makeup, foundation, that, s...
# 21382                                                  []
# 376720  [basketweave, elastic, perfects, the, custom, ...
# 264581  [a, highlighter, that, gives, skin, an, instan...
# 208868                                                 []
# 10763   [from, humble, beginnings, to, a, fully, staff...
# 141506                                                 []
# 84809   [a, sharply, tailored, menswear, silhouette, a...
# 372879  [distinctive, pyramid, studs, highlight, the, ...
# 51626   [a, trim, profile, makes, this, chevronquilted...
# 292782  [this, smartly, designed, slipper, is, shaped,...
# 282439  [an, acnefighting, serum, to, help, target, li...
# 60734   [a, smart, creperubber, sole, adds, some, pop,...
# 172400                                                 []
# 174059  [made, from, classic, denim, and, decorated, w...
#
#                                         match_description  \
# 107867                                                 []
# 366665  [fullcoverage, support, with, a, delightful, s...
# 135770                                                 []
# 15283                                                  []
# 66925                                                  []
# 283289  [ships, free, purchase, estée, lauder, foundat...
# 21382                                                  []
# 376720                                              [nan]
# 264581  [this, product, is, part, of, space, nk, a, lu...
# 208868                                                 []
# 10763                                                  []
# 141506  [this, delicate, panty, is, ultra, comfortable...
# 84809                                                  []
# 372879  [from, the, rockstud, collection, eclectic, ro...
# 51626                                                  []
# 292782                                                 []
# 282439  [what, it, is, an, acne, serum, developed, spe...
# 60734   [fits, narrow, order, one, size, up, lace, up,...
# 172400                                                 []
# 174059                                                 []
#
#                         color
# 107867                [ivory]
# 366665                [ivory]
# 135770                [black]
# 15283                  [pink]
# 66925             [no, color]
# 283289            [1w2, sand]
# 21382                 [black]
# 376720  [light, gold, fabric]
# 264581    [rose, gold, flash]
# 208868                 [navy]
# 10763   [sterling, silver, t]
# 141506                [black]
# 84809                 [olive]
# 372879       [rose, cannelle]
# 51626                 [black]
# 292782                [black]
# 282439            [no, color]
# 60734        [charcoal, grey]
# 172400       [brown, leopard]
# 174059              [riviera]

# %%
corpus.to_csv('processed_Dtrain_4f.csv')

# %% [markdown]
# ### Word2vec model training on above data

# %%
sentences = []
for row in corpus['title']:
    sentences.append(list(row))

# %%
print(sentences[0:30])
# Out:
# [['theory', 'silk', 'shell', 'top', 'ivory', 'small'], ['chantelle', 'lingerie', 'c', 'magnifique', 'seamless', 'unlined', 'minimizer', 'bra', 'ivory', '42d'], ['rag', 'and', 'bone', 'rag', 'and', 'bone', 'shiloh', 'combat', 'boot', 'women', 'black', '9us', '39eu'], ['bixbee', 'kitty', 'water', 'resistant', 'lunchbox', 'kids', 'pink', 'little', 'girl', 'one', 'size'], ['maison', 'francis', 'kurkdjian', 'paris', 'grand', 'soir', 'eau', 'de', 'parfum', 'no', 'color', '68', 'oz'], ['estee', 'lauder', 'estée', 'lauder', 'double', 'wear', 'light', 'soft', 'matte', 'hydra', 'makeup', 'foundation', '1w2', 'sand', 'one', 'size'], ['peter', 'millar', 'hyperlight', 'bit', 'loafer', 'men', 'black', '11'], ['bernie', 'mev', 'fresh', 'buttercup', 'sandal', 'women', 'light', 'gold', 'fabric', '6us', '36eu'], ['hourglass', 'vanish', 'flash', 'highlighting', 'stick', 'rose', 'gold', 'flash', 'one', 'size'], ['fjallraven', 'fjällräven', 'vik', 'wool', 'crewneck', 'sweater', 'navy', 'large'], ['nashelle', 'sterling', 'silver', 'initial', 'disc', 'bracelet', 'sterling', 'silver', 't', 'one', 'size'], ['felina', 'aubrie', 'boy', 'leg', 'briefs', 'black', 'xlarge'], ['wayf', 'finn', 'metallic', 'daisy', 'double', 'breasted', 'blazer', 'olive', 'xsmall'], ['valentino', 'garavani', 'rockstud', 'slingback', 'pump', 'women', 'rose', 'cannelle', '5us', '35eu'], ['kurt', 'geiger', 'london', 'chevron', 'quilted', 'leather', 'card', 'case', 'black', 'one', 'size'], ['ugg®', 'ascot', 'leather', 'slipper', 'men', 'black', '7', 'm'], ['clinique', 'acne', 'solutions', 'acne', 'line', 'correcting', 'serum', 'no', 'color', 'one', 'size'], ['allsaints', 'leigh', 'plain', 'toe', 'derby', 'men', 'charcoal', 'grey', '8', 'm'], ['joules', 'welly', 'print', 'rain', 'boot', 'women', 'brown', 'leopard', '9', 'm'], ['michael', 'michael', 'kors', 'denim', 'jacket', 'plus', 'size', 'riviera', 'plus', '2x'], ['mother', 'the', 'looker', 'high', 'waist', 'crop', 'skinny', 'jeans', 'swimming', 'pool', 'sunday', '24'], ['dolce', 'vita', 'zina', 'plush', 'sneaker', 'women', 'silver', 'glitter', 'multi', '6', 'm'], ['nike', 'flex', 'core', 'golf', 'pants', 'black', 'black', '34', 'x', '32'], ['clarins', 'cleansing', 'sensations', 'duo', 'for', 'drysensitive', 'skin', 'usd', '39', 'value', 'no', 'color', 'one', 'size'], ['dress', 'the', 'population', 'elisa', 'sequin', 'embellished', 'embroidered', 'fit', 'and', 'flare', 'dress', 'papaya', 'multi', 'large'], ['cle', 'de', 'peau', 'clé', 'de', 'peau', 'beauté', 'radiant', 'fluid', 'matte', 'foundation', 'spf', '20', 'b10', 'one', 'size'], ['aravon', 'lia', 'slipon', 'sneaker', 'women', 'black', 'leather', '6', 'b'], ['simplehuman', '4inch', 'sensor', 'makeup', 'mirror', 'compact', 'rose', 'gold', 'one', 'size'], ['dior', 'rouge', 'dior', 'lipstick', 'refill', '525', 'cherie', 'metallic', 'one', 'size'], ['it', 'cosmetics', 'bye', 'bye', 'under', 'eye', 'antiaging', 'waterproof', 'concealer', '455', 'deep', 'ebony', 'c', '04', 'oz']]

# %%
from gensim.models import Word2Vec
from gensim.models.phrases import Phraser, Phrases

model = Word2Vec(sentences, min_count=1, size=200, workers=4, window=5, iter=10)

# %%
model.vector_size   ## embedding dimension
# Out:
# 200

# %%
model.wv.vocab
# Out:
# {'theory': <gensim.models.keyedvectors.Vocab at 0x2765e263358>,
#  'silk': <gensim.models.keyedvectors.Vocab at 0x2765e392f28>,
#  'shell': <gensim.models.keyedvectors.Vocab at 0x2765e392e80>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x2765e392f98>,
#  'ivory': <gensim.models.keyedvectors.Vocab at 0x2765e392eb8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x2765e392fd0>,
#  'chantelle': <gensim.models.keyedvectors.Vocab at 0x2765e3fd048>,
#  'lingerie': <gensim.models.keyedvectors.Vocab at 0x2765e3fd080>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x2765e3fd0b8>,
#  'magnifique': <gensim.models.keyedvectors.Vocab at 0x2765e3fd0f0>,
#  'seamless': <gensim.models.keyedvectors.Vocab at 0x2765e3fd128>,
#  'unlined': <gensim.models.keyedvectors.Vocab at 0x2765e3fd160>,
#  'minimizer': <gensim.models.keyedvectors.Vocab at 0x2765e3fd198>,
#  'bra': <gensim.models.keyedvectors.Vocab at 0x2765e3fd1d0>,
#  '42d': <gensim.models.keyedvectors.Vocab at 0x2765e3fd208>,
#  'rag': <gensim.models.keyedvectors.Vocab at 0x2765e3fd240>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x2765e3fd278>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x2765e3fd2b0>,
#  'shiloh': <gensim.models.keyedvectors.Vocab at 0x2765e3fd2e8>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x2765e3fd320>,
#  'boot': <gensim.models.keyedvectors.Vocab at 0x2765e3fd358>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x2765e3fd390>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x2765e3fd3c8>,
#  '9us': <gensim.models.keyedvectors.Vocab at 0x2765e3fd400>,
#  '39eu': <gensim.models.keyedvectors.Vocab at 0x2765e3fd438>,
#  'bixbee': <gensim.models.keyedvectors.Vocab at 0x2765e3fd470>,
#  'kitty': <gensim.models.keyedvectors.Vocab at 0x2765e3fd4a8>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x2765e3fd4e0>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x2765e3fd518>,
#  'lunchbox': <gensim.models.keyedvectors.Vocab at 0x2765e3fd550>,
#  'kids': <gensim.models.keyedvectors.Vocab at 0x2765e3fd588>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x2765e3fd5c0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x2765e3fd5f8>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x2765e3fd630>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x2765e3fd668>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x2765e3fd6a0>,
#  'maison': <gensim.models.keyedvectors.Vocab at 0x2765e3fd6d8>,
#  'francis': <gensim.models.keyedvectors.Vocab at 0x2765e3fd710>,
#  'kurkdjian': <gensim.models.keyedvectors.Vocab at 0x2765e3fd748>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x2765e3fd780>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x2765e3fd7b8>,
#  'soir': <gensim.models.keyedvectors.Vocab at 0x2765e3fd7f0>,
#  'eau': <gensim.models.keyedvectors.Vocab at 0x2765e3fd828>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x2765e3fd860>,
#  'parfum': <gensim.models.keyedvectors.Vocab at 0x2765e3fd898>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x2765e3fd8d0>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x2765e3fd908>,
#  '68': <gensim.models.keyedvectors.Vocab at 0x2765e3fd940>,
#  'oz': <gensim.models.keyedvectors.Vocab at 0x2765e3fd978>,
#  'estee': <gensim.models.keyedvectors.Vocab at 0x2765e3fd9b0>,
#  'lauder': <gensim.models.keyedvectors.Vocab at 0x2765e3fd9e8>,
#  'estée': <gensim.models.keyedvectors.Vocab at 0x2765e3fda20>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x2765e3fda58>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x2765e3fda90>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x2765e3fdac8>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x2765e3fdb00>,
#  'matte': <gensim.models.keyedvectors.Vocab at 0x2765e3fdb38>,
#  'hydra': <gensim.models.keyedvectors.Vocab at 0x2765e3fdb70>,
#  'makeup': <gensim.models.keyedvectors.Vocab at 0x2765e3fdba8>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x2765e3fdbe0>,
#  '1w2': <gensim.models.keyedvectors.Vocab at 0x2765e3fdc18>,
#  'sand': <gensim.models.keyedvectors.Vocab at 0x2765e3fdc50>,
#  'peter': <gensim.models.keyedvectors.Vocab at 0x2765e3fdc88>,
#  'millar': <gensim.models.keyedvectors.Vocab at 0x2765e3fdcc0>,
#  'hyperlight': <gensim.models.keyedvectors.Vocab at 0x2765e3fdcf8>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x2765e3fdd30>,
#  'loafer': <gensim.models.keyedvectors.Vocab at 0x2765e3fdd68>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x2765e3fdda0>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x2765e3fddd8>,
#  'bernie': <gensim.models.keyedvectors.Vocab at 0x2765e3fde10>,
#  'mev': <gensim.models.keyedvectors.Vocab at 0x2765e3fde48>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x2765e3fde80>,
#  'buttercup': <gensim.models.keyedvectors.Vocab at 0x2765e3fdeb8>,
#  'sandal': <gensim.models.keyedvectors.Vocab at 0x2765e3fdef0>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x2765e3fdf28>,
#  'fabric': <gensim.models.keyedvectors.Vocab at 0x2765e3fdf60>,
#  '6us': <gensim.models.keyedvectors.Vocab at 0x2765e3fdf98>,
#  '36eu': <gensim.models.keyedvectors.Vocab at 0x2765e3fdfd0>,
#  'hourglass': <gensim.models.keyedvectors.Vocab at 0x2765e3fa048>,
#  'vanish': <gensim.models.keyedvectors.Vocab at 0x2765e3fa080>,
#  'flash': <gensim.models.keyedvectors.Vocab at 0x2765e3fa0b8>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x2765e3fa0f0>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x2765e3fa128>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x2765e3fa160>,
#  'fjallraven': <gensim.models.keyedvectors.Vocab at 0x2765e3fa198>,
#  'fjällräven': <gensim.models.keyedvectors.Vocab at 0x2765e3fa1d0>,
#  'vik': <gensim.models.keyedvectors.Vocab at 0x2765e3fa208>,
#  'wool': <gensim.models.keyedvectors.Vocab at 0x2765e3fa240>,
#  'crewneck': <gensim.models.keyedvectors.Vocab at 0x2765e3fa278>,
#  'sweater': <gensim.models.keyedvectors.Vocab at 0x2765e3fa2b0>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x2765e3fa2e8>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x2765e3fa320>,
#  'nashelle': <gensim.models.keyedvectors.Vocab at 0x2765e3fa358>,
#  'sterling': <gensim.models.keyedvectors.Vocab at 0x2765e3fa390>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x2765e3fa3c8>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x2765e3fa400>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x2765e3fa438>,
#  'bracelet': <gensim.models.keyedvectors.Vocab at 0x2765e3fa470>,
#  't': <gensim.models.keyedvectors.Vocab at 0x2765e3fa4a8>,
#  'felina': <gensim.models.keyedvectors.Vocab at 0x2765e3fa4e0>,
#  'aubrie': <gensim.models.keyedvectors.Vocab at 0x2765e3fa518>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x2765e3fa550>,
#  'leg': <gensim.models.keyedvectors.Vocab at 0x2765e3fa588>,
#  'briefs': <gensim.models.keyedvectors.Vocab at 0x2765e3fa5c0>,
#  'xlarge': <gensim.models.keyedvectors.Vocab at 0x2765e3fa5f8>,
#  'wayf': <gensim.models.keyedvectors.Vocab at 0x2765e3fa630>,
#  'finn': <gensim.models.keyedvectors.Vocab at 0x2765e3fa668>,
#  'metallic': <gensim.models.keyedvectors.Vocab at 0x2765e3fa6a0>,
#  'daisy': <gensim.models.keyedvectors.Vocab at 0x2765e3fa6d8>,
#  'breasted': <gensim.models.keyedvectors.Vocab at 0x2765e3fa710>,
#  'blazer': <gensim.models.keyedvectors.Vocab at 0x2765e3fa748>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x2765e3fa780>,
#  'xsmall': <gensim.models.keyedvectors.Vocab at 0x2765e3fa7b8>,
#  'valentino': <gensim.models.keyedvectors.Vocab at 0x2765e3fa7f0>,
#  'garavani': <gensim.models.keyedvectors.Vocab at 0x2765e3fa828>,
#  'rockstud': <gensim.models.keyedvectors.Vocab at 0x2765e3fa860>,
#  'slingback': <gensim.models.keyedvectors.Vocab at 0x2765e3fa898>,
#  'pump': <gensim.models.keyedvectors.Vocab at 0x2765e3fa8d0>,
#  'cannelle': <gensim.models.keyedvectors.Vocab at 0x2765e3fa908>,
#  '5us': <gensim.models.keyedvectors.Vocab at 0x2765e3fa940>,
#  '35eu': <gensim.models.keyedvectors.Vocab at 0x2765e3fa978>,
#  'kurt': <gensim.models.keyedvectors.Vocab at 0x2765e3fa9b0>,
#  'geiger': <gensim.models.keyedvectors.Vocab at 0x2765e3fa9e8>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x2765e3faa20>,
#  'chevron': <gensim.models.keyedvectors.Vocab at 0x2765e3faa58>,
#  'quilted': <gensim.models.keyedvectors.Vocab at 0x2765e3faa90>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x2765e3faac8>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x2765e3fab00>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x2765e3fab38>,
#  'ugg®': <gensim.models.keyedvectors.Vocab at 0x2765e3fab70>,
#  'ascot': <gensim.models.keyedvectors.Vocab at 0x2765e3faba8>,
#  'slipper': <gensim.models.keyedvectors.Vocab at 0x2765e3fabe0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x2765e3fac18>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x2765e3fac50>,
#  'clinique': <gensim.models.keyedvectors.Vocab at 0x2765e3fac88>,
#  'acne': <gensim.models.keyedvectors.Vocab at 0x2765e3facc0>,
#  'solutions': <gensim.models.keyedvectors.Vocab at 0x2765e3facf8>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x2765e3fad30>,
#  'correcting': <gensim.models.keyedvectors.Vocab at 0x2765e3fad68>,
#  'serum': <gensim.models.keyedvectors.Vocab at 0x2765e3fada0>,
#  'allsaints': <gensim.models.keyedvectors.Vocab at 0x2765e3fadd8>,
#  'leigh': <gensim.models.keyedvectors.Vocab at 0x2765e3fae10>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x2765e3fae48>,
#  'toe': <gensim.models.keyedvectors.Vocab at 0x2765e3fae80>,
#  'derby': <gensim.models.keyedvectors.Vocab at 0x2765e3faeb8>,
#  'charcoal': <gensim.models.keyedvectors.Vocab at 0x2765e3faef0>,
#  'grey': <gensim.models.keyedvectors.Vocab at 0x2765e3faf28>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x2765e3faf60>,
#  'joules': <gensim.models.keyedvectors.Vocab at 0x2765e3faf98>,
#  'welly': <gensim.models.keyedvectors.Vocab at 0x2765e3fafd0>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x2765e3fc048>,
#  'rain': <gensim.models.keyedvectors.Vocab at 0x2765e3fc080>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x2765e3fc0b8>,
#  'leopard': <gensim.models.keyedvectors.Vocab at 0x2765e3fc0f0>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x2765e3fc128>,
#  'michael': <gensim.models.keyedvectors.Vocab at 0x2765e3fc160>,
#  'kors': <gensim.models.keyedvectors.Vocab at 0x2765e3fc198>,
#  'denim': <gensim.models.keyedvectors.Vocab at 0x2765e3fc1d0>,
#  'jacket': <gensim.models.keyedvectors.Vocab at 0x2765e3fc208>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x2765e3fc240>,
#  'riviera': <gensim.models.keyedvectors.Vocab at 0x2765e3fc278>,
#  '2x': <gensim.models.keyedvectors.Vocab at 0x2765e3fc2b0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x2765e3fc2e8>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x2765e3fc320>,
#  'looker': <gensim.models.keyedvectors.Vocab at 0x2765e3fc358>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x2765e3fc390>,
#  'waist': <gensim.models.keyedvectors.Vocab at 0x2765e3fc3c8>,
#  'crop': <gensim.models.keyedvectors.Vocab at 0x2765e3fc400>,
#  'skinny': <gensim.models.keyedvectors.Vocab at 0x2765e3fc438>,
#  'jeans': <gensim.models.keyedvectors.Vocab at 0x2765e3fc470>,
#  'swimming': <gensim.models.keyedvectors.Vocab at 0x2765e3fc4a8>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x2765e3fc4e0>,
#  'sunday': <gensim.models.keyedvectors.Vocab at 0x2765e3fc518>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x2765e3fc550>,
#  'dolce': <gensim.models.keyedvectors.Vocab at 0x2765e3fc588>,
#  'vita': <gensim.models.keyedvectors.Vocab at 0x2765e3fc5c0>,
#  'zina': <gensim.models.keyedvectors.Vocab at 0x2765e3fc5f8>,
#  'plush': <gensim.models.keyedvectors.Vocab at 0x2765e3fc630>,
#  'sneaker': <gensim.models.keyedvectors.Vocab at 0x2765e3fc668>,
#  'glitter': <gensim.models.keyedvectors.Vocab at 0x2765e3fc6a0>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x2765e3fc6d8>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x2765e3fc710>,
#  'nike': <gensim.models.keyedvectors.Vocab at 0x2765e3fc748>,
#  'flex': <gensim.models.keyedvectors.Vocab at 0x2765e3fc780>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x2765e3fc7b8>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x2765e3fc7f0>,
#  'pants': <gensim.models.keyedvectors.Vocab at 0x2765e3fc828>,
#  '34': <gensim.models.keyedvectors.Vocab at 0x2765e3fc860>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x2765e3fc898>,
#  '32': <gensim.models.keyedvectors.Vocab at 0x2765e3fc8d0>,
#  'clarins': <gensim.models.keyedvectors.Vocab at 0x2765e3fc908>,
#  'cleansing': <gensim.models.keyedvectors.Vocab at 0x2765e3fc940>,
#  'sensations': <gensim.models.keyedvectors.Vocab at 0x2765e3fc978>,
#  'duo': <gensim.models.keyedvectors.Vocab at 0x2765e3fc9b0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x2765e3fc9e8>,
#  'drysensitive': <gensim.models.keyedvectors.Vocab at 0x2765e3fca20>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x2765e3fca58>,
#  'usd': <gensim.models.keyedvectors.Vocab at 0x2765e3fca90>,
#  '39': <gensim.models.keyedvectors.Vocab at 0x2765e3fcac8>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x2765e3fcb00>,
#  'dress': <gensim.models.keyedvectors.Vocab at 0x2765e3fcb38>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x2765e3fcb70>,
#  'elisa': <gensim.models.keyedvectors.Vocab at 0x2765e3fcba8>,
#  'sequin': <gensim.models.keyedvectors.Vocab at 0x2765e3fcbe0>,
#  'embellished': <gensim.models.keyedvectors.Vocab at 0x2765e3fcc18>,
#  'embroidered': <gensim.models.keyedvectors.Vocab at 0x2765e3fcc50>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x2765e3fcc88>,
#  'flare': <gensim.models.keyedvectors.Vocab at 0x2765e3fccc0>,
#  'papaya': <gensim.models.keyedvectors.Vocab at 0x2765e3fccf8>,
#  'cle': <gensim.models.keyedvectors.Vocab at 0x2765e3fcd30>,
#  'peau': <gensim.models.keyedvectors.Vocab at 0x2765e3fcd68>,
#  'clé': <gensim.models.keyedvectors.Vocab at 0x2765e3fcda0>,
#  'beauté': <gensim.models.keyedvectors.Vocab at 0x2765e3fcdd8>,
#  'radiant': <gensim.models.keyedvectors.Vocab at 0x2765e3fce10>,
#  'fluid': <gensim.models.keyedvectors.Vocab at 0x2765e3fce48>,
#  'spf': <gensim.models.keyedvectors.Vocab at 0x2765e3fce80>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x2765e3fceb8>,
#  'b10': <gensim.models.keyedvectors.Vocab at 0x2765e3fcef0>,
#  'aravon': <gensim.models.keyedvectors.Vocab at 0x2765e3fcf28>,
#  'lia': <gensim.models.keyedvectors.Vocab at 0x2765e3fcf60>,
#  'slipon': <gensim.models.keyedvectors.Vocab at 0x2765e3fcf98>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x2765e3fcfd0>,
#  'simplehuman': <gensim.models.keyedvectors.Vocab at 0x2765e3ff048>,
#  '4inch': <gensim.models.keyedvectors.Vocab at 0x2765e3ff080>,
#  'sensor': <gensim.models.keyedvectors.Vocab at 0x2765e3ff0b8>,
#  'mirror': <gensim.models.keyedvectors.Vocab at 0x2765e3ff0f0>,
#  'compact': <gensim.models.keyedvectors.Vocab at 0x2765e3ff128>,
#  'dior': <gensim.models.keyedvectors.Vocab at 0x2765e3ff160>,
#  'rouge': <gensim.models.keyedvectors.Vocab at 0x2765e3ff198>,
#  'lipstick': <gensim.models.keyedvectors.Vocab at 0x2765e3ff1d0>,
#  'refill': <gensim.models.keyedvectors.Vocab at 0x2765e3ff208>,
#  '525': <gensim.models.keyedvectors.Vocab at 0x2765e3ff240>,
#  'cherie': <gensim.models.keyedvectors.Vocab at 0x2765e3ff278>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x2765e3ff2b0>,
#  'cosmetics': <gensim.models.keyedvectors.Vocab at 0x2765e3ff2e8>,
#  'bye': <gensim.models.keyedvectors.Vocab at 0x2765e3ff320>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x2765e3ff358>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x2765e3ff390>,
#  'antiaging': <gensim.models.keyedvectors.Vocab at 0x2765e3ff3c8>,
#  'waterproof': <gensim.models.keyedvectors.Vocab at 0x2765e3ff400>,
#  'concealer': <gensim.models.keyedvectors.Vocab at 0x2765e3ff438>,
#  '455': <gensim.models.keyedvectors.Vocab at 0x2765e3ff470>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x2765e3ff4a8>,
#  'ebony': <gensim.models.keyedvectors.Vocab at 0x2765e3ff4e0>,
#  '04': <gensim.models.keyedvectors.Vocab at 0x2765e3ff518>,
#  'mazie': <gensim.models.keyedvectors.Vocab at 0x2765e3ff550>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x2765e3ff588>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x2765e3ff5c0>,
#  'wacoal': <gensim.models.keyedvectors.Vocab at 0x2765e3ff5f8>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x2765e3ff630>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x2765e3ff668>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x2765e3ff6a0>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x2765e3ff6d8>,
#  'cappuccino': <gensim.models.keyedvectors.Vocab at 0x2765e3ff710>,
#  'nic': <gensim.models.keyedvectors.Vocab at 0x2765e3ff748>,
#  'zoe': <gensim.models.keyedvectors.Vocab at 0x2765e3ff780>,
#  'niczoe': <gensim.models.keyedvectors.Vocab at 0x2765e3ff7b8>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x2765e3ff7f0>,
#  'vneck': <gensim.models.keyedvectors.Vocab at 0x2765e3ff828>,
#  'hoodie': <gensim.models.keyedvectors.Vocab at 0x2765e3ff860>,
#  'canvas': <gensim.models.keyedvectors.Vocab at 0x2765e3ff898>,
#  'xxlarge': <gensim.models.keyedvectors.Vocab at 0x2765e3ff8d0>,
#  'kenneth': <gensim.models.keyedvectors.Vocab at 0x2765e3ff908>,
#  'cole': <gensim.models.keyedvectors.Vocab at 0x2765e3ff940>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x2765e3ff978>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x2765e3ff9b0>,
#  'olivia': <gensim.models.keyedvectors.Vocab at 0x2765e3ff9e8>,
#  'espadrille': <gensim.models.keyedvectors.Vocab at 0x2765e3ffa20>,
#  'wedge': <gensim.models.keyedvectors.Vocab at 0x2765e3ffa58>,
#  'suede': <gensim.models.keyedvectors.Vocab at 0x2765e3ffa90>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x2765e3ffac8>,
#  'dr': <gensim.models.keyedvectors.Vocab at 0x2765e3ffb00>,
#  'scholls': <gensim.models.keyedvectors.Vocab at 0x2765e3ffb38>,
#  'madison': <gensim.models.keyedvectors.Vocab at 0x2765e3ffb70>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x2765e3ffba8>,
#  '65': <gensim.models.keyedvectors.Vocab at 0x2765e3ffbe0>,
#  'sperry': <gensim.models.keyedvectors.Vocab at 0x2765e3ffc18>,
#  'topsider': <gensim.models.keyedvectors.Vocab at 0x2765e3ffc50>,
#  'authentic': <gensim.models.keyedvectors.Vocab at 0x2765e3ffc88>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x2765e3ffcc0>,
#  'boat': <gensim.models.keyedvectors.Vocab at 0x2765e3ffcf8>,
#  'shoe': <gensim.models.keyedvectors.Vocab at 0x2765e3ffd30>,
#  'walker': <gensim.models.keyedvectors.Vocab at 0x2765e3ffd68>,
#  'toddler': <gensim.models.keyedvectors.Vocab at 0x2765e3ffda0>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x2765d7a50f0>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x2765d7a5128>,
#  'sahara': <gensim.models.keyedvectors.Vocab at 0x2765d7a5358>,
#  'christophe': <gensim.models.keyedvectors.Vocab at 0x2765d7a52b0>,
#  'robin': <gensim.models.keyedvectors.Vocab at 0x27793d629b0>,
#  'regenerating': <gensim.models.keyedvectors.Vocab at 0x27793d62390>,
#  'mask': <gensim.models.keyedvectors.Vocab at 0x2765e3ffdd8>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x2765e3ffe10>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x2765e3ffe48>,
#  'prickly': <gensim.models.keyedvectors.Vocab at 0x2765e3ffe80>,
#  'pear': <gensim.models.keyedvectors.Vocab at 0x2765e3ffeb8>,
#  'seed': <gensim.models.keyedvectors.Vocab at 0x2765e3ffef0>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x2765e3fff28>,
#  'addict': <gensim.models.keyedvectors.Vocab at 0x2765e3fff60>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x2765e3fff98>,
#  'gloss': <gensim.models.keyedvectors.Vocab at 0x2765e3fffd0>,
#  '754': <gensim.models.keyedvectors.Vocab at 0x2765e401048>,
#  'magnify': <gensim.models.keyedvectors.Vocab at 0x2765e401080>,
#  'mac': <gensim.models.keyedvectors.Vocab at 0x2765e4010b8>,
#  'brow': <gensim.models.keyedvectors.Vocab at 0x2765e4010f0>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x2765e401128>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x2765e401160>,
#  'traq': <gensim.models.keyedvectors.Vocab at 0x2765e401198>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x2765e4011d0>,
#  'alegria': <gensim.models.keyedvectors.Vocab at 0x2765e401208>,
#  'qarma': <gensim.models.keyedvectors.Vocab at 0x2765e401240>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x2765e401278>,
#  'paintball': <gensim.models.keyedvectors.Vocab at 0x2765e4012b0>,
#  '775us': <gensim.models.keyedvectors.Vocab at 0x2765e4012e8>,
#  '37eu': <gensim.models.keyedvectors.Vocab at 0x2765e401320>,
#  'nars': <gensim.models.keyedvectors.Vocab at 0x2765e401358>,
#  'sheer': <gensim.models.keyedvectors.Vocab at 0x2765e401390>,
#  'glow': <gensim.models.keyedvectors.Vocab at 0x2765e4013c8>,
#  'vanuatu': <gensim.models.keyedvectors.Vocab at 0x2765e401400>,
#  'chanel': <gensim.models.keyedvectors.Vocab at 0x2765e401438>,
#  'les': <gensim.models.keyedvectors.Vocab at 0x2765e401470>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x2765e4014a8>,
#  'ombres': <gensim.models.keyedvectors.Vocab at 0x2765e4014e0>,
#  'multieffect': <gensim.models.keyedvectors.Vocab at 0x2765e401518>,
#  'quadra': <gensim.models.keyedvectors.Vocab at 0x2765e401550>,
#  'eyeshadow': <gensim.models.keyedvectors.Vocab at 0x2765e401588>,
#  '202': <gensim.models.keyedvectors.Vocab at 0x2765e4015c0>,
#  'tisse': <gensim.models.keyedvectors.Vocab at 0x2765e4015f8>,
#  'camelia': <gensim.models.keyedvectors.Vocab at 0x2765e401630>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x2765e401668>,
#  'spray': <gensim.models.keyedvectors.Vocab at 0x2765e4016a0>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x2765e4016d8>,
#  '3lab': <gensim.models.keyedvectors.Vocab at 0x2765e401710>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x2765e401748>,
#  'lips': <gensim.models.keyedvectors.Vocab at 0x2765e401780>,
#  'hydrating': <gensim.models.keyedvectors.Vocab at 0x2765e4017b8>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x2765e4017f0>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x2765e401828>,
#  '033': <gensim.models.keyedvectors.Vocab at 0x2765e401860>,
#  'studio': <gensim.models.keyedvectors.Vocab at 0x2765e401898>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x2765e4018d0>,
#  'perfecting': <gensim.models.keyedvectors.Vocab at 0x2765e401908>,
#  'nw45': <gensim.models.keyedvectors.Vocab at 0x2765e401940>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x2765e401978>,
#  'artiste': <gensim.models.keyedvectors.Vocab at 0x2765e4019b0>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x2765e4019e8>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x2765e401a20>,
#  'lartiste': <gensim.models.keyedvectors.Vocab at 0x2765e401a58>,
#  'aneria': <gensim.models.keyedvectors.Vocab at 0x2765e401a90>,
#  'clog': <gensim.models.keyedvectors.Vocab at 0x2765e401ac8>,
#  'camel': <gensim.models.keyedvectors.Vocab at 0x2765e401b00>,
#  '758us': <gensim.models.keyedvectors.Vocab at 0x2765e401b38>,
#  '38eu': <gensim.models.keyedvectors.Vocab at 0x2765e401b70>,
#  'ksubi': <gensim.models.keyedvectors.Vocab at 0x2765e401ba8>,
#  'chitch': <gensim.models.keyedvectors.Vocab at 0x2765e401be0>,
#  'boneyard': <gensim.models.keyedvectors.Vocab at 0x2765e401c18>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x2765e401c50>,
#  'minnetonka': <gensim.models.keyedvectors.Vocab at 0x2765e401c88>,
#  'kilty': <gensim.models.keyedvectors.Vocab at 0x2765e401cc0>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x2765e401cf8>,
#  'moccasin': <gensim.models.keyedvectors.Vocab at 0x2765e401d30>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x2765e401d68>,
#  'avanchy': <gensim.models.keyedvectors.Vocab at 0x2765e401da0>,
#  'essentials': <gensim.models.keyedvectors.Vocab at 0x2765e401dd8>,
#  'baby': <gensim.models.keyedvectors.Vocab at 0x2765e401e10>,
#  'dish': <gensim.models.keyedvectors.Vocab at 0x2765e401e48>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x2765e401e80>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x2765e401eb8>,
#  'jordan': <gensim.models.keyedvectors.Vocab at 0x2765e401ef0>,
#  'jumpman': <gensim.models.keyedvectors.Vocab at 0x2765e401f28>,
#  'graphic': <gensim.models.keyedvectors.Vocab at 0x2765e401f60>,
#  'tee': <gensim.models.keyedvectors.Vocab at 0x2765e401f98>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x2765e401fd0>,
#  'heather': <gensim.models.keyedvectors.Vocab at 0x2765e402048>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x2765e402080>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x2765e4020b8>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x2765e4020f0>,
#  'genuine': <gensim.models.keyedvectors.Vocab at 0x2765e402128>,
#  'shearling': <gensim.models.keyedvectors.Vocab at 0x2765e402160>,
#  'lined': <gensim.models.keyedvectors.Vocab at 0x2765e402198>,
#  'chestnut': <gensim.models.keyedvectors.Vocab at 0x2765e4021d0>,
#  'mavi': <gensim.models.keyedvectors.Vocab at 0x2765e402208>,
#  'zach': <gensim.models.keyedvectors.Vocab at 0x2765e402240>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x2765e402278>,
#  'brushed': <gensim.models.keyedvectors.Vocab at 0x2765e4022b0>,
#  'williamsburg': <gensim.models.keyedvectors.Vocab at 0x2765e4022e8>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x2765e402320>,
#  '29': <gensim.models.keyedvectors.Vocab at 0x2765e402358>,
#  'ultra': <gensim.models.keyedvectors.Vocab at 0x2765e402390>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x2765e4023c8>,
#  'teint': <gensim.models.keyedvectors.Vocab at 0x2765e402400>,
#  'ultrawear': <gensim.models.keyedvectors.Vocab at 0x2765e402438>,
#  'allday': <gensim.models.keyedvectors.Vocab at 0x2765e402470>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x2765e4024a8>,
#  'flawless': <gensim.models.keyedvectors.Vocab at 0x2765e4024e0>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x2765e402518>,
#  'br152': <gensim.models.keyedvectors.Vocab at 0x2765e402550>,
#  'yummie': <gensim.models.keyedvectors.Vocab at 0x2765e402588>,
#  'ultralight': <gensim.models.keyedvectors.Vocab at 0x2765e4025c0>,
#  'shaping': <gensim.models.keyedvectors.Vocab at 0x2765e4025f8>,
#  'thong': <gensim.models.keyedvectors.Vocab at 0x2765e402630>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x2765e402668>,
#  'largexlarge': <gensim.models.keyedvectors.Vocab at 0x2765e4026a0>,
#  'agolde': <gensim.models.keyedvectors.Vocab at 0x2765e4026d8>,
#  'riley': <gensim.models.keyedvectors.Vocab at 0x2765e402710>,
#  'ripped': <gensim.models.keyedvectors.Vocab at 0x2765e402748>,
#  'shatter': <gensim.models.keyedvectors.Vocab at 0x2765e402780>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x2765e4027b8>,
#  'mystere': <gensim.models.keyedvectors.Vocab at 0x2765e4027f0>,
#  'mystère': <gensim.models.keyedvectors.Vocab at 0x2765e402828>,
#  'infinite': <gensim.models.keyedvectors.Vocab at 0x2765e402860>,
#  'underwire': <gensim.models.keyedvectors.Vocab at 0x2765e402898>,
#  '34f': <gensim.models.keyedvectors.Vocab at 0x2765e4028d0>,
#  'ddd': <gensim.models.keyedvectors.Vocab at 0x2765e402908>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x2765e402940>,
#  'magic': <gensim.models.keyedvectors.Vocab at 0x2765e402978>,
#  'radiance': <gensim.models.keyedvectors.Vocab at 0x2765e4029b0>,
#  'oribe': <gensim.models.keyedvectors.Vocab at 0x2765e4029e8>,
#  'airbrush': <gensim.models.keyedvectors.Vocab at 0x2765e402a20>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x2765e402a58>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x2765e402a90>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x2765e402ac8>,
#  'blonde': <gensim.models.keyedvectors.Vocab at 0x2765e402b00>,
#  'rockport': <gensim.models.keyedvectors.Vocab at 0x2765e402b38>,
#  'cobb': <gensim.models.keyedvectors.Vocab at 0x2765e402b70>,
#  'hill': <gensim.models.keyedvectors.Vocab at 0x2765e402ba8>,
#  'janna': <gensim.models.keyedvectors.Vocab at 0x2765e402be0>,
#  'perforated': <gensim.models.keyedvectors.Vocab at 0x2765e402c18>,
#  'khaki': <gensim.models.keyedvectors.Vocab at 0x2765e402c50>,
#  'nubuck': <gensim.models.keyedvectors.Vocab at 0x2765e402c88>,
#  'row': <gensim.models.keyedvectors.Vocab at 0x2765e402cc0>,
#  'armando': <gensim.models.keyedvectors.Vocab at 0x2765e402cf8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x2765e402d30>,
#  'cashmere': <gensim.models.keyedvectors.Vocab at 0x2765e402d68>,
#  'cardigan': <gensim.models.keyedvectors.Vocab at 0x2765e402da0>,
#  'melange': <gensim.models.keyedvectors.Vocab at 0x2765e402dd8>,
#  'jen7': <gensim.models.keyedvectors.Vocab at 0x2765e402e10>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x2765e402e48>,
#  'mankind': <gensim.models.keyedvectors.Vocab at 0x2765e402e80>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x2765e402eb8>,
#  'slit': <gensim.models.keyedvectors.Vocab at 0x2765e402ef0>,
#  'capri': <gensim.models.keyedvectors.Vocab at 0x2765e402f28>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x2765e402f60>,
#  'liverpool': <gensim.models.keyedvectors.Vocab at 0x2765e402f98>,
#  'los': <gensim.models.keyedvectors.Vocab at 0x2765e402fd0>,
#  'angeles': <gensim.models.keyedvectors.Vocab at 0x2765e404048>,
#  'scoop': <gensim.models.keyedvectors.Vocab at 0x2765e404080>,
#  'neck': <gensim.models.keyedvectors.Vocab at 0x2765e4040b8>,
#  'tshirt': <gensim.models.keyedvectors.Vocab at 0x2765e4040f0>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x2765e404128>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x2765e404160>,
#  'pomellato': <gensim.models.keyedvectors.Vocab at 0x2765e404198>,
#  'mama': <gensim.models.keyedvectors.Vocab at 0x2765e4041d0>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x2765e404208>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x2765e404240>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x2765e404278>,
#  'cuff': <gensim.models.keyedvectors.Vocab at 0x2765e4042b0>,
#  'moonstone': <gensim.models.keyedvectors.Vocab at 0x2765e4042e8>,
#  'barbour': <gensim.models.keyedvectors.Vocab at 0x2765e404320>,
#  'ashby': <gensim.models.keyedvectors.Vocab at 0x2765e404358>,
#  'wax': <gensim.models.keyedvectors.Vocab at 0x2765e404390>,
#  'lancome': <gensim.models.keyedvectors.Vocab at 0x2765e4043c8>,
#  'lancôme': <gensim.models.keyedvectors.Vocab at 0x2765e404400>,
#  'blush': <gensim.models.keyedvectors.Vocab at 0x2765e404438>,
#  'subtil': <gensim.models.keyedvectors.Vocab at 0x2765e404470>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x2765e4044a8>,
#  'powder': <gensim.models.keyedvectors.Vocab at 0x2765e4044e0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x2765e404518>,
#  'calm': <gensim.models.keyedvectors.Vocab at 0x2765e404550>,
#  'mario': <gensim.models.keyedvectors.Vocab at 0x2765e404588>,
#  'badescu': <gensim.models.keyedvectors.Vocab at 0x2765e4045c0>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x2765e4045f8>,
#  'aloe': <gensim.models.keyedvectors.Vocab at 0x2765e404630>,
#  'chamomile': <gensim.models.keyedvectors.Vocab at 0x2765e404668>,
#  'lavender': <gensim.models.keyedvectors.Vocab at 0x2765e4046a0>,
#  'yves': <gensim.models.keyedvectors.Vocab at 0x2765e4046d8>,
#  'saint': <gensim.models.keyedvectors.Vocab at 0x2765e404710>,
#  'laurent': <gensim.models.keyedvectors.Vocab at 0x2765e404748>,
#  'volupté': <gensim.models.keyedvectors.Vocab at 0x2765e404780>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x2765e4047b8>,
#  'oilinstick': <gensim.models.keyedvectors.Vocab at 0x2765e4047f0>,
#  'balm': <gensim.models.keyedvectors.Vocab at 0x2765e404828>,
#  '89': <gensim.models.keyedvectors.Vocab at 0x2765e404860>,
#  'coach': <gensim.models.keyedvectors.Vocab at 0x2765e404898>,
#  'vierra': <gensim.models.keyedvectors.Vocab at 0x2765e4048d0>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x2765e404908>,
#  'flat': <gensim.models.keyedvectors.Vocab at 0x2765e404940>,
#  'sneake': <gensim.models.keyedvectors.Vocab at 0x2765e404978>,
#  'bobbi': <gensim.models.keyedvectors.Vocab at 0x2765e4049b0>,
#  'buff': <gensim.models.keyedvectors.Vocab at 0x2765e4049e8>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x2765e404a20>,
#  'stu': <gensim.models.keyedvectors.Vocab at 0x2765e404a58>,
#  'lincoln': <gensim.models.keyedvectors.Vocab at 0x2765e404a90>,
#  'moc': <gensim.models.keyedvectors.Vocab at 0x2765e404ac8>,
#  'rustic': <gensim.models.keyedvectors.Vocab at 0x2765e404b00>,
#  '85': <gensim.models.keyedvectors.Vocab at 0x2765e404b38>,
#  'slide': <gensim.models.keyedvectors.Vocab at 0x2765e404b70>,
#  'sam': <gensim.models.keyedvectors.Vocab at 0x2765e404ba8>,
#  'edelman': <gensim.models.keyedvectors.Vocab at 0x2765e404be0>,
#  'yaro': <gensim.models.keyedvectors.Vocab at 0x2765e404c18>,
#  'ankle': <gensim.models.keyedvectors.Vocab at 0x2765e404c50>,
#  'strap': <gensim.models.keyedvectors.Vocab at 0x2765e404c88>,
#  'jute': <gensim.models.keyedvectors.Vocab at 0x2765e404cc0>,
#  'sofft': <gensim.models.keyedvectors.Vocab at 0x2765e404cf8>,
#  'söfft': <gensim.models.keyedvectors.Vocab at 0x2765e404d30>,
#  'somers': <gensim.models.keyedvectors.Vocab at 0x2765e404d68>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x2765e404da0>,
#  'mule': <gensim.models.keyedvectors.Vocab at 0x2765e404dd8>,
#  'cognac': <gensim.models.keyedvectors.Vocab at 0x2765e404e10>,
#  'markstrum': <gensim.models.keyedvectors.Vocab at 0x2765e404e48>,
#  'chelsea': <gensim.models.keyedvectors.Vocab at 0x2765e404e80>,
#  'timex®': <gensim.models.keyedvectors.Vocab at 0x2765e404eb8>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x2765e404ef0>,
#  'bloom': <gensim.models.keyedvectors.Vocab at 0x2765e404f28>,
#  'mesh': <gensim.models.keyedvectors.Vocab at 0x2765e404f60>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x2765e404f98>,
#  '38mm': <gensim.models.keyedvectors.Vocab at 0x2765e404fd0>,
#  'floral': <gensim.models.keyedvectors.Vocab at 0x2765e406048>,
#  'brass': <gensim.models.keyedvectors.Vocab at 0x2765e406080>,
#  'jo': <gensim.models.keyedvectors.Vocab at 0x2765e4060b8>,
#  'malone': <gensim.models.keyedvectors.Vocab at 0x2765e4060f0>,
#  'london™': <gensim.models.keyedvectors.Vocab at 0x2765e406128>,
#  'blossom': <gensim.models.keyedvectors.Vocab at 0x2765e406160>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x2765e406198>,
#  'lotion': <gensim.models.keyedvectors.Vocab at 0x2765e4061d0>,
#  'alex': <gensim.models.keyedvectors.Vocab at 0x2765e406208>,
#  'evenings': <gensim.models.keyedvectors.Vocab at 0x2765e406240>,
#  'burnout': <gensim.models.keyedvectors.Vocab at 0x2765e406278>,
#  'highlow': <gensim.models.keyedvectors.Vocab at 0x2765e4062b0>,
#  'chiffon': <gensim.models.keyedvectors.Vocab at 0x2765e4062e8>,
#  'wrap': <gensim.models.keyedvectors.Vocab at 0x2765e406320>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x2765e406358>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x2765e406390>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x2765e4063c8>,
#  '14w': <gensim.models.keyedvectors.Vocab at 0x2765e406400>,
#  'natori': <gensim.models.keyedvectors.Vocab at 0x2765e406438>,
#  'bliss': <gensim.models.keyedvectors.Vocab at 0x2765e406470>,
#  'cafe': <gensim.models.keyedvectors.Vocab at 0x2765e4064a8>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x2765e4064e0>,
#  'mara': <gensim.models.keyedvectors.Vocab at 0x2765e406518>,
#  'manuela': <gensim.models.keyedvectors.Vocab at 0x2765e406550>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x2765e406588>,
#  'coat': <gensim.models.keyedvectors.Vocab at 0x2765e4065c0>,
#  'liner': <gensim.models.keyedvectors.Vocab at 0x2765e4065f8>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x2765e406630>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x2765e406668>,
#  'moncler': <gensim.models.keyedvectors.Vocab at 0x2765e4066a0>,
#  'causses': <gensim.models.keyedvectors.Vocab at 0x2765e4066d8>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x2765e406710>,
#  'vest': <gensim.models.keyedvectors.Vocab at 0x2765e406748>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x2765e406780>,
#  'seychelles': <gensim.models.keyedvectors.Vocab at 0x2765e4067b8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x2765e4067f0>,
#  'precious': <gensim.models.keyedvectors.Vocab at 0x2765e406828>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x2765e406860>,
#  'doulton': <gensim.models.keyedvectors.Vocab at 0x2765e406898>,
#  'bowls': <gensim.models.keyedvectors.Vocab at 0x2765e4068d0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x2765e406908>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x2765e406940>,
#  '4piece': <gensim.models.keyedvectors.Vocab at 0x2765e406978>,
#  'nesting': <gensim.models.keyedvectors.Vocab at 0x2765e4069b0>,
#  'bowl': <gensim.models.keyedvectors.Vocab at 0x2765e4069e8>,
#  'assorted': <gensim.models.keyedvectors.Vocab at 0x2765e406a20>,
#  'multiactive': <gensim.models.keyedvectors.Vocab at 0x2765e406a58>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x2765e406a90>,
#  'starter': <gensim.models.keyedvectors.Vocab at 0x2765e406ac8>,
#  '87': <gensim.models.keyedvectors.Vocab at 0x2765e406b00>,
#  'scotch': <gensim.models.keyedvectors.Vocab at 0x2765e406b38>,
#  'soda': <gensim.models.keyedvectors.Vocab at 0x2765e406b70>,
#  'overcoat': <gensim.models.keyedvectors.Vocab at 0x2765e406ba8>,
#  'illicit': <gensim.models.keyedvectors.Vocab at 0x2765e406be0>,
#  '016': <gensim.models.keyedvectors.Vocab at 0x2765e406c18>,
#  'vitalumière': <gensim.models.keyedvectors.Vocab at 0x2765e406c50>,
#  'aqua': <gensim.models.keyedvectors.Vocab at 0x2765e406c88>,
#  'sunscreen': <gensim.models.keyedvectors.Vocab at 0x2765e406cc0>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x2765e406cf8>,
#  'spectrum': <gensim.models.keyedvectors.Vocab at 0x2765e406d30>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x2765e406d68>,
#  '132': <gensim.models.keyedvectors.Vocab at 0x2765e406da0>,
#  'chocolat': <gensim.models.keyedvectors.Vocab at 0x2765e406dd8>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x2765e406e10>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x2765e406e48>,
#  'hanro': <gensim.models.keyedvectors.Vocab at 0x2765e406e80>,
#  'allure': <gensim.models.keyedvectors.Vocab at 0x2765e406eb8>,
#  'builtin': <gensim.models.keyedvectors.Vocab at 0x2765e406ef0>,
#  'camisole': <gensim.models.keyedvectors.Vocab at 0x2765e406f28>,
#  'nude': <gensim.models.keyedvectors.Vocab at 0x2765e406f60>,
#  '36c': <gensim.models.keyedvectors.Vocab at 0x2765e406f98>,
#  'eton': <gensim.models.keyedvectors.Vocab at 0x2765e406fd0>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x2765e407048>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x2765e407080>,
#  'shirt': <gensim.models.keyedvectors.Vocab at 0x2765e4070b8>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x2765e4070f0>,
#  '165': <gensim.models.keyedvectors.Vocab at 0x2765e407128>,
#  'aesop': <gensim.models.keyedvectors.Vocab at 0x2765e407160>,
#  'herbal': <gensim.models.keyedvectors.Vocab at 0x2765e407198>,
#  'deodorant': <gensim.models.keyedvectors.Vocab at 0x2765e4071d0>,
#  'mattel': <gensim.models.keyedvectors.Vocab at 0x2765e407208>,
#  'barbie®': <gensim.models.keyedvectors.Vocab at 0x2765e407240>,
#  'portable': <gensim.models.keyedvectors.Vocab at 0x2765e407278>,
#  'onestory': <gensim.models.keyedvectors.Vocab at 0x2765e4072b0>,
#  'dollhouse': <gensim.models.keyedvectors.Vocab at 0x2765e4072e8>,
#  'playset': <gensim.models.keyedvectors.Vocab at 0x2765e407320>,
#  'asst': <gensim.models.keyedvectors.Vocab at 0x2765e407358>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x2765e407390>,
#  'boiing': <gensim.models.keyedvectors.Vocab at 0x2765e4073c8>,
#  'cakeless': <gensim.models.keyedvectors.Vocab at 0x2765e407400>,
#  '09': <gensim.models.keyedvectors.Vocab at 0x2765e407438>,
#  'mediumtan': <gensim.models.keyedvectors.Vocab at 0x2765e407470>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x2765e4074a8>,
#  '017': <gensim.models.keyedvectors.Vocab at 0x2765e4074e0>,
#  'cece': <gensim.models.keyedvectors.Vocab at 0x2765e407518>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x2765e407550>,
#  'shoulder': <gensim.models.keyedvectors.Vocab at 0x2765e407588>,
#  'ruffle': <gensim.models.keyedvectors.Vocab at 0x2765e4075c0>,
#  'blouse': <gensim.models.keyedvectors.Vocab at 0x2765e4075f8>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x2765e407630>,
#  'hunter': <gensim.models.keyedvectors.Vocab at 0x2765e407668>,
#  'refined': <gensim.models.keyedvectors.Vocab at 0x2765e4076a0>,
#  '075': <gensim.models.keyedvectors.Vocab at 0x2765e4076d8>,
#  'walnut': <gensim.models.keyedvectors.Vocab at 0x2765e407710>,
#  'chantecaille': <gensim.models.keyedvectors.Vocab at 0x2765e407748>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x2765e407780>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x2765e4077b8>,
#  'idole': <gensim.models.keyedvectors.Vocab at 0x2765e4077f0>,
#  'camouflage': <gensim.models.keyedvectors.Vocab at 0x2765e407828>,
#  'corrector': <gensim.models.keyedvectors.Vocab at 0x2765e407860>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x2765e407898>,
#  'liddesdale®': <gensim.models.keyedvectors.Vocab at 0x2765e4078d0>,
#  'tailored': <gensim.models.keyedvectors.Vocab at 0x2765e407908>,
#  'nylon': <gensim.models.keyedvectors.Vocab at 0x2765e407940>,
#  'thierry': <gensim.models.keyedvectors.Vocab at 0x2765e407978>,
#  'mugler': <gensim.models.keyedvectors.Vocab at 0x2765e4079b0>,
#  'angel': <gensim.models.keyedvectors.Vocab at 0x2765e4079e8>,
#  'toilette': <gensim.models.keyedvectors.Vocab at 0x2765e407a20>,
#  'wolf': <gensim.models.keyedvectors.Vocab at 0x2765e407a58>,
#  'palermo': <gensim.models.keyedvectors.Vocab at 0x2765e407a90>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x2765e407ac8>,
#  'deposit': <gensim.models.keyedvectors.Vocab at 0x2765e407b00>,
#  'jewelry': <gensim.models.keyedvectors.Vocab at 0x2765e407b38>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x2765e407b70>,
#  'buxom': <gensim.models.keyedvectors.Vocab at 0x2765e407ba8>,
#  'lash': <gensim.models.keyedvectors.Vocab at 0x2765e407be0>,
#  'volumizing': <gensim.models.keyedvectors.Vocab at 0x2765e407c18>,
#  'mascara': <gensim.models.keyedvectors.Vocab at 0x2765e407c50>,
#  'madewell': <gensim.models.keyedvectors.Vocab at 0x2765e407c88>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x2765e407cc0>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x2765e407cf8>,
#  'baccarat': <gensim.models.keyedvectors.Vocab at 0x2765e407d30>,
#  'massena': <gensim.models.keyedvectors.Vocab at 0x2765e407d68>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x2765e407da0>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x2765e407dd8>,
#  'goblet': <gensim.models.keyedvectors.Vocab at 0x2765e407e10>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x2765e407e48>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x2765e407e80>,
#  'harmony': <gensim.models.keyedvectors.Vocab at 0x2765e407eb8>,
#  'knit': <gensim.models.keyedvectors.Vocab at 0x2765e407ef0>,
#  'ballet': <gensim.models.keyedvectors.Vocab at 0x2765e407f28>,
#  'timberland': <gensim.models.keyedvectors.Vocab at 0x2765e407f60>,
#  'inch': <gensim.models.keyedvectors.Vocab at 0x2765e407f98>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x2765e407fd0>,
#  'revitalizing': <gensim.models.keyedvectors.Vocab at 0x2765e409048>,
#  'supreme': <gensim.models.keyedvectors.Vocab at 0x2765e409080>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x2765e4090b8>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x2765e4090f0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x2765e409128>,
#  'crème': <gensim.models.keyedvectors.Vocab at 0x2765e409160>,
#  'barefoot': <gensim.models.keyedvectors.Vocab at 0x2765e409198>,
#  'dreams®': <gensim.models.keyedvectors.Vocab at 0x2765e4091d0>,
#  'cozychic™': <gensim.models.keyedvectors.Vocab at 0x2765e409208>,
#  'disney': <gensim.models.keyedvectors.Vocab at 0x2765e409240>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x2765e409278>,
#  'hooded': <gensim.models.keyedvectors.Vocab at 0x2765e4092b0>,
#  'robe': <gensim.models.keyedvectors.Vocab at 0x2765e4092e8>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x2765e409320>,
#  'smallmedium': <gensim.models.keyedvectors.Vocab at 0x2765e409358>,
#  'gabbana': <gensim.models.keyedvectors.Vocab at 0x2765e409390>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x2765e4093c8>,
#  'dolceandgabbana': <gensim.models.keyedvectors.Vocab at 0x2765e409400>,
#  '139': <gensim.models.keyedvectors.Vocab at 0x2765e409438>,
#  'commando': <gensim.models.keyedvectors.Vocab at 0x2765e409470>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x2765e4094a8>,
#  'stokke': <gensim.models.keyedvectors.Vocab at 0x2765e4094e0>,
#  'flexi': <gensim.models.keyedvectors.Vocab at 0x2765e409518>,
#  'bath®': <gensim.models.keyedvectors.Vocab at 0x2765e409550>,
#  'foldable': <gensim.models.keyedvectors.Vocab at 0x2765e409588>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x2765e4095c0>,
#  'tub': <gensim.models.keyedvectors.Vocab at 0x2765e4095f8>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x2765e409630>,
#  'plug': <gensim.models.keyedvectors.Vocab at 0x2765e409668>,
#  'infant': <gensim.models.keyedvectors.Vocab at 0x2765e4096a0>,
#  'insert': <gensim.models.keyedvectors.Vocab at 0x2765e4096d8>,
#  'transparent': <gensim.models.keyedvectors.Vocab at 0x2765e409710>,
#  'jewel': <gensim.models.keyedvectors.Vocab at 0x2765e409748>,
#  'badgley': <gensim.models.keyedvectors.Vocab at 0x2765e409780>,
#  'mischka': <gensim.models.keyedvectors.Vocab at 0x2765e4097b8>,
#  'royalty': <gensim.models.keyedvectors.Vocab at 0x2765e4097f0>,
#  'eileen': <gensim.models.keyedvectors.Vocab at 0x2765e409828>,
#  'fisher': <gensim.models.keyedvectors.Vocab at 0x2765e409860>,
#  'tapered': <gensim.models.keyedvectors.Vocab at 0x2765e409898>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x2765e4098d0>,
#  '3x': <gensim.models.keyedvectors.Vocab at 0x2765e409908>,
#  'elia': <gensim.models.keyedvectors.Vocab at 0x2765e409940>,
#  'flames': <gensim.models.keyedvectors.Vocab at 0x2765e409978>,
#  'mock': <gensim.models.keyedvectors.Vocab at 0x2765e4099b0>,
#  'bodysuit': <gensim.models.keyedvectors.Vocab at 0x2765e4099e8>,
#  '00': <gensim.models.keyedvectors.Vocab at 0x2765e409a20>,
#  'guerlain': <gensim.models.keyedvectors.Vocab at 0x2765e409a58>,
#  'mon': <gensim.models.keyedvectors.Vocab at 0x2765e409a90>,
#  '33': <gensim.models.keyedvectors.Vocab at 0x2765e409ac8>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x2765e409b00>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x2765e409b38>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x2765e409b70>,
#  'icy': <gensim.models.keyedvectors.Vocab at 0x2765e409ba8>,
#  'diamonds': <gensim.models.keyedvectors.Vocab at 0x2765e409be0>,
#  'combo': <gensim.models.keyedvectors.Vocab at 0x2765e409c18>,
#  'fab': <gensim.models.keyedvectors.Vocab at 0x2765e409c50>,
#  '556us': <gensim.models.keyedvectors.Vocab at 0x2765e409c88>,
#  'marlyn': <gensim.models.keyedvectors.Vocab at 0x2765e409cc0>,
#  'athletic': <gensim.models.keyedvectors.Vocab at 0x2765e409cf8>,
#  'slim': <gensim.models.keyedvectors.Vocab at 0x2765e409d30>,
#  'everton': <gensim.models.keyedvectors.Vocab at 0x2765e409d68>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x2765e409da0>,
#  'smashbox': <gensim.models.keyedvectors.Vocab at 0x2765e409dd8>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x2765e409e10>,
#  'cheek': <gensim.models.keyedvectors.Vocab at 0x2765e409e48>,
#  'brush': <gensim.models.keyedvectors.Vocab at 0x2765e409e80>,
#  'deluxe': <gensim.models.keyedvectors.Vocab at 0x2765e409eb8>,
#  'soothing': <gensim.models.keyedvectors.Vocab at 0x2765e409ef0>,
#  'cleanse': <gensim.models.keyedvectors.Vocab at 0x2765e409f28>,
#  '96': <gensim.models.keyedvectors.Vocab at 0x2765e409f60>,
#  'asics®': <gensim.models.keyedvectors.Vocab at 0x2765e409f98>,
#  'novablast': <gensim.models.keyedvectors.Vocab at 0x2765e409fd0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x2765e40b048>,
#  'blackblack': <gensim.models.keyedvectors.Vocab at 0x2765e40b080>,
#  '75': <gensim.models.keyedvectors.Vocab at 0x2765e40b0b8>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x2765e40b0f0>,
#  '210': <gensim.models.keyedvectors.Vocab at 0x2765e40b128>,
#  'precise': <gensim.models.keyedvectors.Vocab at 0x2765e40b160>,
#  'eyeliner': <gensim.models.keyedvectors.Vocab at 0x2765e40b198>,
#  'ag': <gensim.models.keyedvectors.Vocab at 0x2765e40b1d0>,
#  'exboyfriend': <gensim.models.keyedvectors.Vocab at 0x2765e40b208>,
#  'distressed': <gensim.models.keyedvectors.Vocab at 0x2765e40b240>,
#  '22': <gensim.models.keyedvectors.Vocab at 0x2765e40b278>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x2765e40b2b0>,
#  'landmark': <gensim.models.keyedvectors.Vocab at 0x2765e40b2e8>,
#  'destructed': <gensim.models.keyedvectors.Vocab at 0x2765e40b320>,
#  'bugatchi': <gensim.models.keyedvectors.Vocab at 0x2765e40b358>,
#  'shaped': <gensim.models.keyedvectors.Vocab at 0x2765e40b390>,
#  'buttonup': <gensim.models.keyedvectors.Vocab at 0x2765e40b3c8>,
#  'johnnieo': <gensim.models.keyedvectors.Vocab at 0x2765e40b400>,
#  'birdie': <gensim.models.keyedvectors.Vocab at 0x2765e40b438>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x2765e40b470>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x2765e40b4a8>,
#  'polo': <gensim.models.keyedvectors.Vocab at 0x2765e40b4e0>,
#  'neptune': <gensim.models.keyedvectors.Vocab at 0x2765e40b518>,
#  'acorn': <gensim.models.keyedvectors.Vocab at 0x2765e40b550>,
#  'berber': <gensim.models.keyedvectors.Vocab at 0x2765e40b588>,
#  'vince': <gensim.models.keyedvectors.Vocab at 0x2765e40b5c0>,
#  'camuto': <gensim.models.keyedvectors.Vocab at 0x2765e40b5f8>,
#  'salindera': <gensim.models.keyedvectors.Vocab at 0x2765e40b630>,
#  '55': <gensim.models.keyedvectors.Vocab at 0x2765e40b668>,
#  'vanish™': <gensim.models.keyedvectors.Vocab at 0x2765e40b6a0>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x2765e40b6d8>,
#  'golden': <gensim.models.keyedvectors.Vocab at 0x2765e40b710>,
#  'cushion': <gensim.models.keyedvectors.Vocab at 0x2765e40b748>,
#  'o20': <gensim.models.keyedvectors.Vocab at 0x2765e40b780>,
#  'ochre': <gensim.models.keyedvectors.Vocab at 0x2765e40b7b8>,
#  'diptyque': <gensim.models.keyedvectors.Vocab at 0x2765e40b7f0>,
#  'tubéreuse': <gensim.models.keyedvectors.Vocab at 0x2765e40b828>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x2765e40b860>,
#  'bb': <gensim.models.keyedvectors.Vocab at 0x2765e40b898>,
#  'dakota': <gensim.models.keyedvectors.Vocab at 0x2765e40b8d0>,
#  'private': <gensim.models.keyedvectors.Vocab at 0x2765e40b908>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x2765e40b940>,
#  'pleated': <gensim.models.keyedvectors.Vocab at 0x2765e40b978>,
#  'faux': <gensim.models.keyedvectors.Vocab at 0x2765e40b9b0>,
#  'miniskirt': <gensim.models.keyedvectors.Vocab at 0x2765e40b9e8>,
#  'joes': <gensim.models.keyedvectors.Vocab at 0x2765e40ba20>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x2765e40ba58>,
#  'refillable': <gensim.models.keyedvectors.Vocab at 0x2765e40ba90>,
#  '846': <gensim.models.keyedvectors.Vocab at 0x2765e40bac8>,
#  'concorde': <gensim.models.keyedvectors.Vocab at 0x2765e40bb00>,
#  'herschel': <gensim.models.keyedvectors.Vocab at 0x2765e40bb38>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x2765e40bb70>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x2765e40bba8>,
#  'chapter': <gensim.models.keyedvectors.Vocab at 0x2765e40bbe0>,
#  'carryon': <gensim.models.keyedvectors.Vocab at 0x2765e40bc18>,
#  'dopp': <gensim.models.keyedvectors.Vocab at 0x2765e40bc50>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x2765e40bc88>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x2765e40bcc0>,
#  'mclip®': <gensim.models.keyedvectors.Vocab at 0x2765e40bcf8>,
#  'enamel': <gensim.models.keyedvectors.Vocab at 0x2765e40bd30>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x2765e40bd68>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x2765e40bda0>,
#  '1state': <gensim.models.keyedvectors.Vocab at 0x2765e40bdd8>,
#  'cranberry': <gensim.models.keyedvectors.Vocab at 0x2765e40be10>,
#  'david': <gensim.models.keyedvectors.Vocab at 0x2765e40be48>,
#  'donahue': <gensim.models.keyedvectors.Vocab at 0x2765e40be80>,
#  'cummerbund': <gensim.models.keyedvectors.Vocab at 0x2765e40beb8>,
#  'bow': <gensim.models.keyedvectors.Vocab at 0x2765e40bef0>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x2765e40bf28>,
#  'satin': <gensim.models.keyedvectors.Vocab at 0x2765e40bf60>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x2765e40bf98>,
#  'juicy': <gensim.models.keyedvectors.Vocab at 0x2765e40bfd0>,
#  'tubes': <gensim.models.keyedvectors.Vocab at 0x2765e40d048>,
#  '05': <gensim.models.keyedvectors.Vocab at 0x2765e40d080>,
#  'marshmallow': <gensim.models.keyedvectors.Vocab at 0x2765e40d0b8>,
#  'electro': <gensim.models.keyedvectors.Vocab at 0x2765e40d0f0>,
#  'versace': <gensim.models.keyedvectors.Vocab at 0x2765e40d128>,
#  'greca': <gensim.models.keyedvectors.Vocab at 0x2765e40d160>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x2765e40d198>,
#  '45mm': <gensim.models.keyedvectors.Vocab at 0x2765e40d1d0>,
#  'kaine': <gensim.models.keyedvectors.Vocab at 0x2765e40d208>,
#  'backpack': <gensim.models.keyedvectors.Vocab at 0x2765e40d240>,
#  'laid': <gensim.models.keyedvectors.Vocab at 0x2765e40d278>,
#  'giraffe': <gensim.models.keyedvectors.Vocab at 0x2765e40d2b0>,
#  'luxe': <gensim.models.keyedvectors.Vocab at 0x2765e40d2e8>,
#  'blanket': <gensim.models.keyedvectors.Vocab at 0x2765e40d320>,
#  'zoom': <gensim.models.keyedvectors.Vocab at 0x2765e40d358>,
#  'pegasus': <gensim.models.keyedvectors.Vocab at 0x2765e40d390>,
#  '37': <gensim.models.keyedvectors.Vocab at 0x2765e40d3c8>,
#  'blackwhite': <gensim.models.keyedvectors.Vocab at 0x2765e40d400>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x2765e40d438>,
#  'babybjorn': <gensim.models.keyedvectors.Vocab at 0x2765e40d470>,
#  'babybjörn': <gensim.models.keyedvectors.Vocab at 0x2765e40d4a8>,
#  'carrier': <gensim.models.keyedvectors.Vocab at 0x2765e40d4e0>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x2765e40d518>,
#  'blanca': <gensim.models.keyedvectors.Vocab at 0x2765e40d550>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x2765e40d588>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x2765e40d5c0>,
#  'onepiece': <gensim.models.keyedvectors.Vocab at 0x2765e40d5f8>,
#  'swimsuit': <gensim.models.keyedvectors.Vocab at 0x2765e40d630>,
#  'darby': <gensim.models.keyedvectors.Vocab at 0x2765e40d668>,
#  'crisscross': <gensim.models.keyedvectors.Vocab at 0x2765e40d6a0>,
#  'luggage': <gensim.models.keyedvectors.Vocab at 0x2765e40d6d8>,
#  'vachetta': <gensim.models.keyedvectors.Vocab at 0x2765e40d710>,
#  'stripe': <gensim.models.keyedvectors.Vocab at 0x2765e40d748>,
#  '155': <gensim.models.keyedvectors.Vocab at 0x2765e40d780>,
#  'becca': <gensim.models.keyedvectors.Vocab at 0x2765e40d7b8>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x2765e40d7f0>,
#  'coverage': <gensim.models.keyedvectors.Vocab at 0x2765e40d828>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x2765e40d860>,
#  '3w3': <gensim.models.keyedvectors.Vocab at 0x2765e40d898>,
#  'yurman': <gensim.models.keyedvectors.Vocab at 0x2765e40d8d0>,
#  'châtelaine': <gensim.models.keyedvectors.Vocab at 0x2765e40d908>,
#  'earrings': <gensim.models.keyedvectors.Vocab at 0x2765e40d940>,
#  'semiprecious': <gensim.models.keyedvectors.Vocab at 0x2765e40d978>,
#  'stones': <gensim.models.keyedvectors.Vocab at 0x2765e40d9b0>,
#  'hampton': <gensim.models.keyedvectors.Vocab at 0x2765e40d9e8>,
#  'topaz': <gensim.models.keyedvectors.Vocab at 0x2765e40da20>,
#  'keen': <gensim.models.keyedvectors.Vocab at 0x2765e40da58>,
#  'lorelai': <gensim.models.keyedvectors.Vocab at 0x2765e40da90>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x2765e40dac8>,
#  'jane': <gensim.models.keyedvectors.Vocab at 0x2765e40db00>,
#  'olukai': <gensim.models.keyedvectors.Vocab at 0x2765e40db38>,
#  'punua': <gensim.models.keyedvectors.Vocab at 0x2765e40db70>,
#  'olu': <gensim.models.keyedvectors.Vocab at 0x2765e40dba8>,
#  'ash': <gensim.models.keyedvectors.Vocab at 0x2765e40dbe0>,
#  'lau': <gensim.models.keyedvectors.Vocab at 0x2765e40dc18>,
#  'oneill': <gensim.models.keyedvectors.Vocab at 0x2765e40dc50>,
#  'stockton': <gensim.models.keyedvectors.Vocab at 0x2765e40dc88>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x2765e40dcc0>,
#  'shorts': <gensim.models.keyedvectors.Vocab at 0x2765e40dcf8>,
#  'havaianas': <gensim.models.keyedvectors.Vocab at 0x2765e40dd30>,
#  'flip': <gensim.models.keyedvectors.Vocab at 0x2765e40dd68>,
#  'flop': <gensim.models.keyedvectors.Vocab at 0x2765e40dda0>,
#  'nina': <gensim.models.keyedvectors.Vocab at 0x2765e40ddd8>,
#  'nelena': <gensim.models.keyedvectors.Vocab at 0x2765e40de10>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x2765e40de48>,
#  '105': <gensim.models.keyedvectors.Vocab at 0x2765e40de80>,
#  'burberry': <gensim.models.keyedvectors.Vocab at 0x2765e40deb8>,
#  '52mm': <gensim.models.keyedvectors.Vocab at 0x2765e40def0>,
#  'gradient': <gensim.models.keyedvectors.Vocab at 0x2765e40df28>,
#  'square': <gensim.models.keyedvectors.Vocab at 0x2765e40df60>,
#  'sunglasses': <gensim.models.keyedvectors.Vocab at 0x2765e40df98>,
#  'havana': <gensim.models.keyedvectors.Vocab at 0x2765e40dfd0>,
#  'mephisto': <gensim.models.keyedvectors.Vocab at 0x2765e40e048>,
#  'agatha': <gensim.models.keyedvectors.Vocab at 0x2765e40e080>,
#  'bootie': <gensim.models.keyedvectors.Vocab at 0x2765e40e0b8>,
#  'hazelnut': <gensim.models.keyedvectors.Vocab at 0x2765e40e0f0>,
#  'fabiana': <gensim.models.keyedvectors.Vocab at 0x2765e40e128>,
#  'filippi': <gensim.models.keyedvectors.Vocab at 0x2765e40e160>,
#  'collar': <gensim.models.keyedvectors.Vocab at 0x2765e40e198>,
#  'poplin': <gensim.models.keyedvectors.Vocab at 0x2765e40e1d0>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x2765e40e208>,
#  'osprey': <gensim.models.keyedvectors.Vocab at 0x2765e40e240>,
#  'aphelia': <gensim.models.keyedvectors.Vocab at 0x2765e40e278>,
#  '26l': <gensim.models.keyedvectors.Vocab at 0x2765e40e2b0>,
#  'funnel': <gensim.models.keyedvectors.Vocab at 0x2765e40e2e8>,
#  'serge': <gensim.models.keyedvectors.Vocab at 0x2765e40e320>,
#  'lutens': <gensim.models.keyedvectors.Vocab at 0x2765e40e358>,
#  'clair': <gensim.models.keyedvectors.Vocab at 0x2765e40e390>,
#  'musc': <gensim.models.keyedvectors.Vocab at 0x2765e40e3c8>,
#  'marco': <gensim.models.keyedvectors.Vocab at 0x2765e40e400>,
#  'bicego': <gensim.models.keyedvectors.Vocab at 0x2765e40e438>,
#  'lunaria': <gensim.models.keyedvectors.Vocab at 0x2765e40e470>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x2765e40e4a8>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x2765e40e4e0>,
#  'icebreaker': <gensim.models.keyedvectors.Vocab at 0x2765e40e518>,
#  'crush': <gensim.models.keyedvectors.Vocab at 0x2765e40e550>,
#  'jogger': <gensim.models.keyedvectors.Vocab at 0x2765e40e588>,
#  'jet': <gensim.models.keyedvectors.Vocab at 0x2765e40e5c0>,
#  'hthrdnu': <gensim.models.keyedvectors.Vocab at 0x2765e40e5f8>,
#  'sunray': <gensim.models.keyedvectors.Vocab at 0x2765e40e630>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x2765e40e668>,
#  'psychic': <gensim.models.keyedvectors.Vocab at 0x2765e40e6a0>,
#  'fuchsiablack': <gensim.models.keyedvectors.Vocab at 0x2765e40e6d8>,
#  'dl': <gensim.models.keyedvectors.Vocab at 0x2765e40e710>,
#  '1961': <gensim.models.keyedvectors.Vocab at 0x2765e40e748>,
#  'dl1961': <gensim.models.keyedvectors.Vocab at 0x2765e40e780>,
#  'stretch': <gensim.models.keyedvectors.Vocab at 0x2765e40e7b8>,
#  '2t': <gensim.models.keyedvectors.Vocab at 0x2765e40e7f0>,
#  'keds®': <gensim.models.keyedvectors.Vocab at 0x2765e40e828>,
#  'jambu': <gensim.models.keyedvectors.Vocab at 0x2765e40e860>,
#  'naomi': <gensim.models.keyedvectors.Vocab at 0x2765e40e898>,
#  'tory': <gensim.models.keyedvectors.Vocab at 0x2765e40e8d0>,
#  'burch': <gensim.models.keyedvectors.Vocab at 0x2765e40e908>,
#  'lila': <gensim.models.keyedvectors.Vocab at 0x2765e40e940>,
#  'equestrian': <gensim.models.keyedvectors.Vocab at 0x2765e40e978>,
#  'softwalk®': <gensim.models.keyedvectors.Vocab at 0x2765e40e9b0>,
#  'sonora': <gensim.models.keyedvectors.Vocab at 0x2765e40e9e8>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x2765e40ea20>,
#  'lucky': <gensim.models.keyedvectors.Vocab at 0x2765e40ea58>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x2765e40ea90>,
#  'mixed': <gensim.models.keyedvectors.Vocab at 0x2765e40eac8>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x2765e40eb00>,
#  'thyme': <gensim.models.keyedvectors.Vocab at 0x2765e40eb38>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x2765e40eb70>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x2765e40eba8>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x2765e40ebe0>,
#  '5n2': <gensim.models.keyedvectors.Vocab at 0x2765e40ec18>,
#  'amber': <gensim.models.keyedvectors.Vocab at 0x2765e40ec50>,
#  'volcom': <gensim.models.keyedvectors.Vocab at 0x2765e40ec88>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x2765e40ecc0>,
#  'logo': <gensim.models.keyedvectors.Vocab at 0x2765e40ecf8>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x2765e40ed30>,
#  'shirred': <gensim.models.keyedvectors.Vocab at 0x2765e40ed68>,
#  'sleeve': <gensim.models.keyedvectors.Vocab at 0x2765e40eda0>,
#  'noir': <gensim.models.keyedvectors.Vocab at 0x2765e40edd8>,
#  'xxsmall': <gensim.models.keyedvectors.Vocab at 0x2765e40ee10>,
#  'stuart': <gensim.models.keyedvectors.Vocab at 0x2765e40ee48>,
#  'weitzman': <gensim.models.keyedvectors.Vocab at 0x2765e40ee80>,
#  'nearlynude': <gensim.models.keyedvectors.Vocab at 0x2765e40eeb8>,
#  'adobe': <gensim.models.keyedvectors.Vocab at 0x2765e40eef0>,
#  'patent': <gensim.models.keyedvectors.Vocab at 0x2765e40ef28>,
#  '45': <gensim.models.keyedvectors.Vocab at 0x2765e40ef60>,
#  'barbara': <gensim.models.keyedvectors.Vocab at 0x2765e40ef98>,
#  'sturm': <gensim.models.keyedvectors.Vocab at 0x2765e40efd0>,
#  'brightening': <gensim.models.keyedvectors.Vocab at 0x2765e560048>,
#  'kingsburg': <gensim.models.keyedvectors.Vocab at 0x2765e560080>,
#  'quiksilver': <gensim.models.keyedvectors.Vocab at 0x2765e5600b8>,
#  'heritage': <gensim.models.keyedvectors.Vocab at 0x2765e5600f0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x2765e560128>,
#  'rashguard': <gensim.models.keyedvectors.Vocab at 0x2765e560160>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x2765e560198>,
#  'laura': <gensim.models.keyedvectors.Vocab at 0x2765e5601d0>,
#  'mercier': <gensim.models.keyedvectors.Vocab at 0x2765e560208>,
#  'illuminator': <gensim.models.keyedvectors.Vocab at 0x2765e560240>,
#  'indiscretion': <gensim.models.keyedvectors.Vocab at 0x2765e560278>,
#  'illusion': <gensim.models.keyedvectors.Vocab at 0x2765e5602b0>,
#  'wireless': <gensim.models.keyedvectors.Vocab at 0x2765e5602e8>,
#  '38d': <gensim.models.keyedvectors.Vocab at 0x2765e560320>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x2765e560358>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x2765e560390>,
#  'houndstooth': <gensim.models.keyedvectors.Vocab at 0x2765e5603c8>,
#  'houndstooth001': <gensim.models.keyedvectors.Vocab at 0x2765e560400>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x2765e560438>,
#  'fits': <gensim.models.keyedvectors.Vocab at 0x2765e560470>,
#  '1216': <gensim.models.keyedvectors.Vocab at 0x2765e5604a8>,
#  'blanknyc': <gensim.models.keyedvectors.Vocab at 0x2765e5604e0>,
#  'snowed': <gensim.models.keyedvectors.Vocab at 0x2765e560518>,
#  'fur': <gensim.models.keyedvectors.Vocab at 0x2765e560550>,
#  'topshop': <gensim.models.keyedvectors.Vocab at 0x2765e560588>,
#  'bucket': <gensim.models.keyedvectors.Vocab at 0x2765e5605c0>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x2765e5605f8>,
#  'ruby': <gensim.models.keyedvectors.Vocab at 0x2765e560630>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x2765e560668>,
#  'graphite': <gensim.models.keyedvectors.Vocab at 0x2765e5606a0>,
#  '2090': <gensim.models.keyedvectors.Vocab at 0x2765e5606d8>,
#  'whiteparticle': <gensim.models.keyedvectors.Vocab at 0x2765e560710>,
#  'outerknown': <gensim.models.keyedvectors.Vocab at 0x2765e560748>,
#  'hightide': <gensim.models.keyedvectors.Vocab at 0x2765e560780>,
#  'sweatshirt': <gensim.models.keyedvectors.Vocab at 0x2765e5607b8>,
#  'pitch': <gensim.models.keyedvectors.Vocab at 0x2765e5607f0>,
#  'touche': <gensim.models.keyedvectors.Vocab at 0x2765e560828>,
#  'éclat': <gensim.models.keyedvectors.Vocab at 0x2765e560860>,
#  'br25': <gensim.models.keyedvectors.Vocab at 0x2765e560898>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x2765e5608d0>,
#  'beige': <gensim.models.keyedvectors.Vocab at 0x2765e560908>,
#  'temple': <gensim.models.keyedvectors.Vocab at 0x2765e560940>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x2765e560978>,
#  'claire': <gensim.models.keyedvectors.Vocab at 0x2765e5609b0>,
#  'turquoise': <gensim.models.keyedvectors.Vocab at 0x2765e5609e8>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x2765e560a20>,
#  'turquoisediamond': <gensim.models.keyedvectors.Vocab at 0x2765e560a58>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x2765e560a90>,
#  'buckle': <gensim.models.keyedvectors.Vocab at 0x2765e560ac8>,
#  '18k': <gensim.models.keyedvectors.Vocab at 0x2765e560b00>,
#  '5mm': <gensim.models.keyedvectors.Vocab at 0x2765e560b38>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x2765e560b70>,
#  ...}

# %%
len(model.wv.vocab)   ## vocabulary size (no of words in vocabulary)
# Out:
# 30850

# %% [markdown]
# ### similarity check between words

# %%
model.most_similar('sneaker')
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('shoe', 0.6532991528511047),
#  ('sandal', 0.5749198198318481),
#  ('loafer', 0.5713566541671753),
#  ('flop', 0.5508825778961182),
#  ('slide', 0.5371812582015991),
#  ('boot', 0.5257828235626221),
#  ('bootie', 0.5125555396080017),
#  ('oxford', 0.48931097984313965),
#  ('flat', 0.4891081154346466),
#  ('slipper', 0.47657954692840576)]

# %%
model.most_similar('jacket')
# Out:
# C:\Users\Akshay\.conda\envs\pytorchenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('vest', 0.7261949777603149),
#  ('parka', 0.6648017168045044),
#  ('coat', 0.6530815362930298),
#  ('raincoat', 0.6095454096794128),
#  ('miniskirt', 0.5625578165054321),
#  ('anorak', 0.5494288802146912),
#  ('joggers', 0.5468044281005859),
#  ('leggings', 0.5272932052612305),
#  ('pullover', 0.5267577171325684),
#  ('sweatpants', 0.5079219937324524)]

# %%
from gensim.test.utils import common_texts

bigram_transformer = Phrases(common_texts)
model = Word2Vec(bigram_transformer[common_texts], min_count=1)

# %% [markdown]
# #### Training features (title, description, match_description, color)

# %%
corpus = pd.read_csv('processed_Dtrain_4f.csv')

# %%
corpus.head()
# Out:
#    Unnamed: 0                                              title  \
# 0      107867  ['theory', 'silk', 'shell', 'top', 'ivory', 's...
# 1      366665  ['chantelle', 'lingerie', 'c', 'magnifique', '...
# 2      135770  ['rag', 'and', 'bone', 'rag', 'and', 'bone', '...
# 3       15283  ['bixbee', 'kitty', 'water', 'resistant', 'lun...
# 4       66925  ['maison', 'francis', 'kurkdjian', 'paris', 'g...
#
#                                          description  \
# 0                                                 []
# 1  ['designed', 'to', 'minimize', 'your', 'bustli...
# 2  ['side', 'panels', 'lend', 'a', 'bit', 'of', '...
# 3  ['the', 'face', 'of', 'a', 'pretty', 'kitty', ...
# 4  ['a', 'sophisticated', 'and', 'concentrated', ...
#
#                                    match_description            color
# 0                                                 []        ['ivory']
# 1  ['fullcoverage', 'support', 'with', 'a', 'deli...        ['ivory']
# 2                                                 []        ['black']
# 3                                                 []         ['pink']
# 4                                                 []  ['no', 'color']

# %%
sentences = []
for row in corpus['title']:
    sentences.append(row)

for row in corpus['description']:
    sentences.append(row)
    
for row in corpus['match_description']:
    sentences.append(row)
    
for row in corpus['color']:
    sentences.append(row)

# %%
len(sentences)
# Out:
# 1232164

# %%
from gensim.models import Word2Vec

model = Word2Vec(sentences, min_count=1, size=200, workers=6, window=7, iter=30)

# %%
len(model.wv.vocab)
# Out:
# 115

# %%
model.wv.vocab
# Out:
# {'[': <gensim.models.keyedvectors.Vocab at 0x1e9460bd630>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x1e9460b97f0>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1e9460b9748>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x1e9460b9e48>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1e9460b9e80>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x1e9460b9eb8>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x1e9460b9ef0>,
#  'y': <gensim.models.keyedvectors.Vocab at 0x1e9460b9f60>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1e9460b9f98>,
#  ' ': <gensim.models.keyedvectors.Vocab at 0x1e9460b9fd0>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1e9460b9f28>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1e9460b9860>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x1e9460b92b0>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x1e949053048>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x1e949053080>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x1e9490530b8>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1e9490530f0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1e949053128>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x1e949053160>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1e949053198>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x1e9490531d0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1e949053208>,
#  'f': <gensim.models.keyedvectors.Vocab at 0x1e949053240>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x1e949053278>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1e9490532b0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x1e9490532e8>,
#  'z': <gensim.models.keyedvectors.Vocab at 0x1e949053320>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x1e949053358>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1e949053390>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1e9490533c8>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x1e949053400>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1e949053438>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1e949053470>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x1e9490534a8>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x1e9490534e0>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1e949053518>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x1e949053550>,
#  'é': <gensim.models.keyedvectors.Vocab at 0x1e949053588>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1e9490535c0>,
#  'ä': <gensim.models.keyedvectors.Vocab at 0x1e9490535f8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1e949053630>,
#  '®': <gensim.models.keyedvectors.Vocab at 0x1e949053668>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1e9490536a0>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1e9490536d8>,
#  'è': <gensim.models.keyedvectors.Vocab at 0x1e949053710>,
#  'ô': <gensim.models.keyedvectors.Vocab at 0x1e949053748>,
#  'ö': <gensim.models.keyedvectors.Vocab at 0x1e949053780>,
#  '™': <gensim.models.keyedvectors.Vocab at 0x1e9490537b8>,
#  'â': <gensim.models.keyedvectors.Vocab at 0x1e9490537f0>,
#  'ø': <gensim.models.keyedvectors.Vocab at 0x1e949053828>,
#  'ò': <gensim.models.keyedvectors.Vocab at 0x1e949053860>,
#  'ü': <gensim.models.keyedvectors.Vocab at 0x1e949053898>,
#  'í': <gensim.models.keyedvectors.Vocab at 0x1e9490538d0>,
#  'à': <gensim.models.keyedvectors.Vocab at 0x1e949053908>,
#  'á': <gensim.models.keyedvectors.Vocab at 0x1e949053940>,
#  'å': <gensim.models.keyedvectors.Vocab at 0x1e949053978>,
#  'ê': <gensim.models.keyedvectors.Vocab at 0x1e9490539b0>,
#  'î': <gensim.models.keyedvectors.Vocab at 0x1e9490539e8>,
#  '²': <gensim.models.keyedvectors.Vocab at 0x1e949053a20>,
#  'ë': <gensim.models.keyedvectors.Vocab at 0x1e949053a58>,
#  'ÿ': <gensim.models.keyedvectors.Vocab at 0x1e949053a90>,
#  'ì': <gensim.models.keyedvectors.Vocab at 0x1e949053ac8>,
#  'ç': <gensim.models.keyedvectors.Vocab at 0x1e949053b00>,
#  '°': <gensim.models.keyedvectors.Vocab at 0x1e949053b38>,
#  'º': <gensim.models.keyedvectors.Vocab at 0x1e949053b70>,
#  '³': <gensim.models.keyedvectors.Vocab at 0x1e949053ba8>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x1e949053be0>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x1e949053c18>,
#  'û': <gensim.models.keyedvectors.Vocab at 0x1e949053c50>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x1e949053c88>,
#  'ñ': <gensim.models.keyedvectors.Vocab at 0x1e949053cc0>,
#  'ï': <gensim.models.keyedvectors.Vocab at 0x1e949053cf8>,
#  '—': <gensim.models.keyedvectors.Vocab at 0x1e949053d30>,
#  'ã': <gensim.models.keyedvectors.Vocab at 0x1e949053d68>,
#  '\\': <gensim.models.keyedvectors.Vocab at 0x1e949053da0>,
#  '¹': <gensim.models.keyedvectors.Vocab at 0x1e949053dd8>,
#  '·': <gensim.models.keyedvectors.Vocab at 0x1e949053e10>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1e949053e48>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1e949053e80>,
#  'ó': <gensim.models.keyedvectors.Vocab at 0x1e949053eb8>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x1e949053ef0>,
#  '⁄': <gensim.models.keyedvectors.Vocab at 0x1e949053f28>,
#  '½': <gensim.models.keyedvectors.Vocab at 0x1e949053f60>,
#  '¿': <gensim.models.keyedvectors.Vocab at 0x1e949053f98>,
#  '„': <gensim.models.keyedvectors.Vocab at 0x1e949053fd0>,
#  '¢': <gensim.models.keyedvectors.Vocab at 0x1e949056048>,
#  '•': <gensim.models.keyedvectors.Vocab at 0x1e949056080>,
#  '€': <gensim.models.keyedvectors.Vocab at 0x1e9490560b8>,
#  'ׁ': <gensim.models.keyedvectors.Vocab at 0x1e9490560f0>,
#  '˘': <gensim.models.keyedvectors.Vocab at 0x1e949056128>,
#  '−': <gensim.models.keyedvectors.Vocab at 0x1e949056160>,
#  'ß': <gensim.models.keyedvectors.Vocab at 0x1e949056198>,
#  '©': <gensim.models.keyedvectors.Vocab at 0x1e9490561d0>,
#  '┬': <gensim.models.keyedvectors.Vocab at 0x1e949056208>,
#  '«': <gensim.models.keyedvectors.Vocab at 0x1e949056240>,
#  'ā': <gensim.models.keyedvectors.Vocab at 0x1e949056278>,
#  '¾': <gensim.models.keyedvectors.Vocab at 0x1e9490562b0>,
#  '¼': <gensim.models.keyedvectors.Vocab at 0x1e9490562e8>,
#  '℃': <gensim.models.keyedvectors.Vocab at 0x1e949056320>,
#  'ō': <gensim.models.keyedvectors.Vocab at 0x1e949056358>,
#  '¬': <gensim.models.keyedvectors.Vocab at 0x1e949056390>,
#  'ē': <gensim.models.keyedvectors.Vocab at 0x1e9490563c8>,
#  '‚': <gensim.models.keyedvectors.Vocab at 0x1e949056400>,
#  '―': <gensim.models.keyedvectors.Vocab at 0x1e949056438>,
#  'ª': <gensim.models.keyedvectors.Vocab at 0x1e949056470>,
#  'æ': <gensim.models.keyedvectors.Vocab at 0x1e9490564a8>,
#  '×': <gensim.models.keyedvectors.Vocab at 0x1e9490564e0>,
#  'ۤ': <gensim.models.keyedvectors.Vocab at 0x1e949056518>,
#  '❘': <gensim.models.keyedvectors.Vocab at 0x1e949056550>,
#  'ù': <gensim.models.keyedvectors.Vocab at 0x1e949056588>,
#  '㥷': <gensim.models.keyedvectors.Vocab at 0x1e9490565c0>,
#  '̊': <gensim.models.keyedvectors.Vocab at 0x1e9490565f8>,
#  '⁵': <gensim.models.keyedvectors.Vocab at 0x1e949056630>,
#  'β': <gensim.models.keyedvectors.Vocab at 0x1e949056668>,
#  'N': <gensim.models.keyedvectors.Vocab at 0x1e9490566a0>}

# %%
## training with context-window = 5, iter=10

model = Word2Vec(sentences, min_count=1, size=200, workers=6, window=5, iter=10)

# %%
len(model.wv.vocab)
# Out:
# 115

# %%
## reconstructing the training corpus to exclude - color feature (1-gram)
sentences = []
for row in corpus['title']:
    sentences.append(row)

for row in corpus['description']:
    sentences.append(row)
    
for row in corpus['match_description']:
    sentences.append(row)

# %%
len(sentences)
# Out:
# 924123

# %%
## training with context-window = 5, iter=10 for above data (3 features excluding color)

model = Word2Vec(sentences, min_count=1, size=200, workers=6, window=5, iter=10)

# %%
len(model.wv.vocab)
# Out:
# 114

# %%
## reconstructing the training corpus to include only title and description
sentences = []
for row in corpus['title']:
    sentences.append(row)

for row in corpus['description']:
    sentences.append(row)

# %%
model = Word2Vec(sentences, min_count=1, size=200, workers=6, window=5, iter=10)

# %%
len(model.wv.vocab)
# Out:
# 81

# %%
## reconstructing only with title

sentences = []
for row in corpus['title']:
    sentences.append(row)

# %%
print(sentences[0:30])
# Out:
# ["['theory', 'silk', 'shell', 'top', 'ivory', 'small']", "['chantelle', 'lingerie', 'c', 'magnifique', 'seamless', 'unlined', 'minimizer', 'bra', 'ivory', '42d']", "['rag', 'and', 'bone', 'rag', 'and', 'bone', 'shiloh', 'combat', 'boot', 'women', 'black', '9us', '39eu']", "['bixbee', 'kitty', 'water', 'resistant', 'lunchbox', 'kids', 'pink', 'little', 'girl', 'one', 'size']", "['maison', 'francis', 'kurkdjian', 'paris', 'grand', 'soir', 'eau', 'de', 'parfum', 'no', 'color', '68', 'oz']", "['estee', 'lauder', 'estée', 'lauder', 'double', 'wear', 'light', 'soft', 'matte', 'hydra', 'makeup', 'foundation', '1w2', 'sand', 'one', 'size']", "['peter', 'millar', 'hyperlight', 'bit', 'loafer', 'men', 'black', '11']", "['bernie', 'mev', 'fresh', 'buttercup', 'sandal', 'women', 'light', 'gold', 'fabric', '6us', '36eu']", "['hourglass', 'vanish', 'flash', 'highlighting', 'stick', 'rose', 'gold', 'flash', 'one', 'size']", "['fjallraven', 'fjällräven', 'vik', 'wool', 'crewneck', 'sweater', 'navy', 'large']", "['nashelle', 'sterling', 'silver', 'initial', 'disc', 'bracelet', 'sterling', 'silver', 't', 'one', 'size']", "['felina', 'aubrie', 'boy', 'leg', 'briefs', 'black', 'xlarge']", "['wayf', 'finn', 'metallic', 'daisy', 'double', 'breasted', 'blazer', 'olive', 'xsmall']", "['valentino', 'garavani', 'rockstud', 'slingback', 'pump', 'women', 'rose', 'cannelle', '5us', '35eu']", "['kurt', 'geiger', 'london', 'chevron', 'quilted', 'leather', 'card', 'case', 'black', 'one', 'size']", "['ugg®', 'ascot', 'leather', 'slipper', 'men', 'black', '7', 'm']", "['clinique', 'acne', 'solutions', 'acne', 'line', 'correcting', 'serum', 'no', 'color', 'one', 'size']", "['allsaints', 'leigh', 'plain', 'toe', 'derby', 'men', 'charcoal', 'grey', '8', 'm']", "['joules', 'welly', 'print', 'rain', 'boot', 'women', 'brown', 'leopard', '9', 'm']", "['michael', 'michael', 'kors', 'denim', 'jacket', 'plus', 'size', 'riviera', 'plus', '2x']", "['mother', 'the', 'looker', 'high', 'waist', 'crop', 'skinny', 'jeans', 'swimming', 'pool', 'sunday', '24']", "['dolce', 'vita', 'zina', 'plush', 'sneaker', 'women', 'silver', 'glitter', 'multi', '6', 'm']", "['nike', 'flex', 'core', 'golf', 'pants', 'black', 'black', '34', 'x', '32']", "['clarins', 'cleansing', 'sensations', 'duo', 'for', 'drysensitive', 'skin', 'usd', '39', 'value', 'no', 'color', 'one', 'size']", "['dress', 'the', 'population', 'elisa', 'sequin', 'embellished', 'embroidered', 'fit', 'and', 'flare', 'dress', 'papaya', 'multi', 'large']", "['cle', 'de', 'peau', 'clé', 'de', 'peau', 'beauté', 'radiant', 'fluid', 'matte', 'foundation', 'spf', '20', 'b10', 'one', 'size']", "['aravon', 'lia', 'slipon', 'sneaker', 'women', 'black', 'leather', '6', 'b']", "['simplehuman', '4inch', 'sensor', 'makeup', 'mirror', 'compact', 'rose', 'gold', 'one', 'size']", "['dior', 'rouge', 'dior', 'lipstick', 'refill', '525', 'cherie', 'metallic', 'one', 'size']", "['it', 'cosmetics', 'bye', 'bye', 'under', 'eye', 'antiaging', 'waterproof', 'concealer', '455', 'deep', 'ebony', 'c', '04', 'oz']"]

# %%
model = Word2Vec(sentences, min_count=1, size=200, workers=6, window=5, iter=10)

# %%
len(model.wv.vocab)
# Out:
# 76

# %%
sentences = []
for row in corpus['title']:
    sentences.append(list(row))

# %%
print(sentences[0:30])
# Out:
# [['[', "'", 't', 'h', 'e', 'o', 'r', 'y', "'", ',', ' ', "'", 's', 'i', 'l', 'k', "'", ',', ' ', "'", 's', 'h', 'e', 'l', 'l', "'", ',', ' ', "'", 't', 'o', 'p', "'", ',', ' ', "'", 'i', 'v', 'o', 'r', 'y', "'", ',', ' ', "'", 's', 'm', 'a', 'l', 'l', "'", ']'], ['[', "'", 'c', 'h', 'a', 'n', 't', 'e', 'l', 'l', 'e', "'", ',', ' ', "'", 'l', 'i', 'n', 'g', 'e', 'r', 'i', 'e', "'", ',', ' ', "'", 'c', "'", ',', ' ', "'", 'm', 'a', 'g', 'n', 'i', 'f', 'i', 'q', 'u', 'e', "'", ',', ' ', "'", 's', 'e', 'a', 'm', 'l', 'e', 's', 's', "'", ',', ' ', "'", 'u', 'n', 'l', 'i', 'n', 'e', 'd', "'", ',', ' ', "'", 'm', 'i', 'n', 'i', 'm', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'b', 'r', 'a', "'", ',', ' ', "'", 'i', 'v', 'o', 'r', 'y', "'", ',', ' ', "'", '4', '2', 'd', "'", ']'], ['[', "'", 'r', 'a', 'g', "'", ',', ' ', "'", 'a', 'n', 'd', "'", ',', ' ', "'", 'b', 'o', 'n', 'e', "'", ',', ' ', "'", 'r', 'a', 'g', "'", ',', ' ', "'", 'a', 'n', 'd', "'", ',', ' ', "'", 'b', 'o', 'n', 'e', "'", ',', ' ', "'", 's', 'h', 'i', 'l', 'o', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', 'b', 'a', 't', "'", ',', ' ', "'", 'b', 'o', 'o', 't', "'", ',', ' ', "'", 'w', 'o', 'm', 'e', 'n', "'", ',', ' ', "'", 'b', 'l', 'a', 'c', 'k', "'", ',', ' ', "'", '9', 'u', 's', "'", ',', ' ', "'", '3', '9', 'e', 'u', "'", ']'], ['[', "'", 'b', 'i', 'x', 'b', 'e', 'e', "'", ',', ' ', "'", 'k', 'i', 't', 't', 'y', "'", ',', ' ', "'", 'w', 'a', 't', 'e', 'r', "'", ',', ' ', "'", 'r', 'e', 's', 'i', 's', 't', 'a', 'n', 't', "'", ',', ' ', "'", 'l', 'u', 'n', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'k', 'i', 'd', 's', "'", ',', ' ', "'", 'p', 'i', 'n', 'k', "'", ',', ' ', "'", 'l', 'i', 't', 't', 'l', 'e', "'", ',', ' ', "'", 'g', 'i', 'r', 'l', "'", ',', ' ', "'", 'o', 'n', 'e', "'", ',', ' ', "'", 's', 'i', 'z', 'e', "'", ']'], ['[', "'", 'm', 'a', 'i', 's', 'o', 'n', "'", ',', ' ', "'", 'f', 'r', 'a', 'n', 'c', 'i', 's', "'", ',', ' ', "'", 'k', 'u', 'r', 'k', 'd', 'j', 'i', 'a', 'n', "'", ',', ' ', "'", 'p', 'a', 'r', 'i', 's', "'", ',', ' ', "'", 'g', 'r', 'a', 'n', 'd', "'", ',', ' ', "'", 's', 'o', 'i', 'r', "'", ',', ' ', "'", 'e', 'a', 'u', "'", ',', ' ', "'", 'd', 'e', "'", ',', ' ', "'", 'p', 'a', 'r', 'f', 'u', 'm', "'", ',', ' ', "'", 'n', 'o', "'", ',', ' ', "'", 'c', 'o', 'l', 'o', 'r', "'", ',', ' ', "'", '6', '8', "'", ',', ' ', "'", 'o', 'z', "'", ']'], ['[', "'", 'e', 's', 't', 'e', 'e', "'", ',', ' ', "'", 'l', 'a', 'u', 'd', 'e', 'r', "'", ',', ' ', "'", 'e', 's', 't', 'é', 'e', "'", ',', ' ', "'", 'l', 'a', 'u', 'd', 'e', 'r', "'", ',', ' ', "'", 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'w', 'e', 'a', 'r', "'", ',', ' ', "'", 'l', 'i', 'g', 'h', 't', "'", ',', ' ', "'", 's', 'o', 'f', 't', "'", ',', ' ', "'", 'm', 'a', 't', 't', 'e', "'", ',', ' ', "'", 'h', 'y', 'd', 'r', 'a', "'", ',', ' ', "'", 'm', 'a', 'k', 'e', 'u', 'p', "'", ',', ' ', "'", 'f', 'o', 'u', 'n', 'd', 'a', 't', 'i', 'o', 'n', "'", ',', ' ', "'", '1', 'w', '2', "'", ',', ' ', "'", 's', 'a', 'n', 'd', "'", ',', ' ', "'", 'o', 'n', 'e', "'", ',', ' ', "'", 's', 'i', 'z', 'e', "'", ']'], ['[', "'", 'p', 'e', 't', 'e', 'r', "'", ',', ' ', "'", 'm', 'i', 'l', 'l', 'a', 'r', "'", ',', ' ', "'", 'h', 'y', 'p', 'e', 'r', 'l', 'i', 'g', 'h', 't', "'", ',', ' ', "'", 'b', 'i', 't', "'", ',', ' ', "'", 'l', 'o', 'a', 'f', 'e', 'r', "'", ',', ' ', "'", 'm', 'e', 'n', "'", ',', ' ', "'", 'b', 'l', 'a', 'c', 'k', "'", ',', ' ', "'", '1', '1', "'", ']'], ['[', "'", 'b', 'e', 'r', 'n', 'i', 'e', "'", ',', ' ', "'", 'm', 'e', 'v', "'", ',', ' ', "'", 'f', 'r', 'e', 's', 'h', "'", ',', ' ', "'", 'b', 'u', 't', 't', 'e', 'r', 'c', 'u', 'p', "'", ',', ' ', "'", 's', 'a', 'n', 'd', 'a', 'l', "'", ',', ' ', "'", 'w', 'o', 'm', 'e', 'n', "'", ',', ' ', "'", 'l', 'i', 'g', 'h', 't', "'", ',', ' ', "'", 'g', 'o', 'l', 'd', "'", ',', ' ', "'", 'f', 'a', 'b', 'r', 'i', 'c', "'", ',', ' ', "'", '6', 'u', 's', "'", ',', ' ', "'", '3', '6', 'e', 'u', "'", ']'], ['[', "'", 'h', 'o', 'u', 'r', 'g', 'l ...
